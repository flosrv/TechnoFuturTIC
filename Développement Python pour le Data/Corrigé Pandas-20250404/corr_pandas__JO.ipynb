# %% [markdown]
# # Execices d'introduction Pandas: olympic-dataset

# %%
# 1) Importation de la librairie pandas 
import numpy as np
import pandas as pd

# %%
# 2) Importation du fichier csv 
data = pd.read_csv('./data/Exercices_Pandas_athlete_events.csv')

# %%
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
import os
li = os.listdir('./data')

# %%
li
# Out:
# ['Exercices_Pandas_athlete_events.csv', 'Exercices_Pandas_athlete_events.zip']

# %%
# 3) Afficher les 5 premières lignes afin de voir si l’importation est correct (fonction : head()) 
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
# 4)	Afficher les 5 dernière lignes (fonction tail() ) 
data.tail(5)
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
#5)	Afficher les informations sur le dataframe (le nombre de ligne, colonne, le nombre nan, le type de colonne) 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
data.index
# Out:
# RangeIndex(start=0, stop=271116, step=1)

# %%
# 6)	Afficher les dimensions du dataframe (la méthode shape) 
data.shape
# Out:
# (271116, 15)

# %%
data.iloc[0]
# Out:
# ID                                  1
# Name                        A Dijiang
# Sex                                 M
# Age                              24.0
# Height                          180.0
# Weight                           80.0
# Team                            China
# NOC                               CHN
# Games                     1992 Summer
# Year                             1992
# Season                         Summer
# City                        Barcelona
# Sport                      Basketball
# Event     Basketball Men's Basketball
# Medal                             NaN
# Name: 0, dtype: object

# %%
len(data), len(data.iloc[0])
# Out:
# (271116, 15)

# %%
# 7)	Afficher les statistiques descriptives du dataframe 
data.describe() # par défaut que numérique
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data.describe(include='all')
# Out:
#                    ID                  Name     Sex            Age  \
# count   271116.000000                271116  271116  261642.000000
# unique            NaN                134732       2            NaN
# top               NaN  Robert Tait McKenzie       M            NaN
# freq              NaN                    58  196594            NaN
# mean     68248.954396                   NaN     NaN      25.556898
# std      39022.286345                   NaN     NaN       6.393561
# min          1.000000                   NaN     NaN      10.000000
# 25%      34643.000000                   NaN     NaN      21.000000
# 50%      68205.000000                   NaN     NaN      24.000000
# 75%     102097.250000                   NaN     NaN      28.000000
# max     135571.000000                   NaN     NaN      97.000000
#
#                Height         Weight           Team     NOC        Games  \
# count   210945.000000  208241.000000         271116  271116       271116
# ...

# %%
data.select_dtypes('object').describe()
# Out:
#                         Name     Sex           Team     NOC        Games  \
# count                 271116  271116         271116  271116       271116
# unique                134732       2           1184     230           51
# top     Robert Tait McKenzie       M  United States     USA  2000 Summer
# freq                      58  196594          17847   18853        13821
#
#         Season    City      Sport                    Event  Medal
# count   271116  271116     271116                   271116  39783
# unique       2      42         66                      765      3
# top     Summer  London  Athletics  Football Men's Football   Gold
# freq    222552   22426      38624                     5733  13372

# %%
cols = ['Name','Sex','Team']
data[cols].describe()
# Out:
#                         Name     Sex           Team
# count                 271116  271116         271116
# unique                134732       2           1184
# top     Robert Tait McKenzie       M  United States
# freq                      58  196594          17847

# %%
# 8)	Compter le nombre de valeur null dans le dataframe 
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 363853

# %%
# 9)	Sélectionner la colonne Edition et afficher (selon 3 manières) 
#edition = Games
display(data.Games)
print('-'*30)
col = 'Games'
display(data[col])
print('-'*30)
display(data.loc[:,col])
# Out:
# 0         1992 Summer
# 1         2012 Summer
# 2         1920 Summer
# 3         1900 Summer
# 4         1988 Winter
#              ...
# 271111    1976 Winter
# 271112    2014 Winter
# 271113    2014 Winter
# 271114    1998 Winter
# 271115    2002 Winter
# Name: Games, Length: 271116, dtype: object
# ------------------------------
# 0         1992 Summer
# 1         2012 Summer
# 2         1920 Summer
# 3         1900 Summer
# 4         1988 Winter
#              ...
# 271111    1976 Winter
# 271112    2014 Winter
# 271113    2014 Winter
# 271114    1998 Winter
# 271115    2002 Winter
# Name: Games, Length: 271116, dtype: object
# ------------------------------
# 0         1992 Summer
# 1         2012 Summer
# 2         1920 Summer
# 3         1900 Summer
# 4         1988 Winter
#              ...
# 271111    1976 Winter
# 271112    2014 Winter
# 271113    2014 Winter
# 271114    1998 Winter
# 271115    2002 Winter
# Name: Games, Length: 271116, dtype: object

# %%
# 10)	Sélectionner la colonne Name et afficher le résultat en triant par ordre alphabétique 
(data['Name'].str.strip()).sort_values(ascending=True).head()


#data['Name'].sort_values(ascending=True).head().values
# Out:
# 0                        A Dijiang
# 1                         A Lamusi
# 153340    A. Aanantha Sambu Mayavo
# 528                A. Abdul Razzak
# 529                A. Abdul Razzak
# Name: Name, dtype: object

# %%
# 11)	Sélectionner les colonnes Event, city, Name, Medal 
cols = ['Event','City','Name','Medal']
data[cols].head(3)
data[['Event','City','Name','Medal']].head()
# Out:
#                               Event       City                      Name Medal
# 0       Basketball Men's Basketball  Barcelona                 A Dijiang   NaN
# 1      Judo Men's Extra-Lightweight     London                  A Lamusi   NaN
# 2           Football Men's Football  Antwerpen       Gunnar Nielsen Aaby   NaN
# 3       Tug-Of-War Men's Tug-Of-War      Paris      Edgar Lindenau Aabye  Gold
# 4  Speed Skating Women's 500 metres    Calgary  Christine Jacoba Aaftink   NaN

# %%
# 12)	Slicer les lignes de 0 à 25 du dataframe au moyen du iloc 
#data.iloc[0:25]

# %%
# 13)	Filtrer la discipline Football de 2 manières différentes 
is_foot = data['Sport'] == 'Football'
data[is_foot].head(3)
# Out:
#      ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 2     3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
# 105  37   Ann Kristin Aarnes   F  23.0   182.0    64.0   Norway  NOR
# 116  41             Rolf Aas   M  28.0     NaN     NaN   Norway  NOR
#
#            Games  Year  Season       City     Sport  \
# 2    1920 Summer  1920  Summer  Antwerpen  Football
# 105  1996 Summer  1996  Summer    Atlanta  Football
# 116  1920 Summer  1920  Summer  Antwerpen  Football
#
#                          Event   Medal
# 2      Football Men's Football     NaN
# 105  Football Women's Football  Bronze
# 116    Football Men's Football     NaN

# %%
data.query("Sport=='Football'").head(3)
# Out:
#      ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 2     3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
# 105  37   Ann Kristin Aarnes   F  23.0   182.0    64.0   Norway  NOR
# 116  41             Rolf Aas   M  28.0     NaN     NaN   Norway  NOR
#
#            Games  Year  Season       City     Sport  \
# 2    1920 Summer  1920  Summer  Antwerpen  Football
# 105  1996 Summer  1996  Summer    Atlanta  Football
# 116  1920 Summer  1920  Summer  Antwerpen  Football
#
#                          Event   Medal
# 2      Football Men's Football     NaN
# 105  Football Women's Football  Bronze
# 116    Football Men's Football     NaN

# %%
# 14)	Filtrer le dataframe sur la saison Summer et stocker les lignes dans une nouvelle variable appelée « ete »

ete = data[data['Season']=='Summer']

# %%
#15)	Filtrer le dataframe sur la saison Winter et stocker les lignes dans une nouvelle variable appelée « hiver » 
hiver= data[data['Season']=='Winter']
hiver= data.loc[data['Season']=='Winter',:] # loc[idx, liste_col]  +-= where

# %% [markdown]
# hiver:
#
# SELECT *
# FROM data
#
# WHERE Season == 'Winter'

# %%
#16)	Afficher de manière unique tous les sports 

print(data['Sport'].sort_values().unique()) # unique +-= distinct

GB = data[['Sport','ID']].groupby('Sport').count()
display(GB)

display(data[['Sport']].groupby('Sport').sample())

display(data['Sport'].drop_duplicates())
# Out:
# ['Aeronautics' 'Alpine Skiing' 'Alpinism' 'Archery' 'Art Competitions'
#  'Athletics' 'Badminton' 'Baseball' 'Basketball' 'Basque Pelota'
#  'Beach Volleyball' 'Biathlon' 'Bobsleigh' 'Boxing' 'Canoeing' 'Cricket'
#  'Croquet' 'Cross Country Skiing' 'Curling' 'Cycling' 'Diving'
#  'Equestrianism' 'Fencing' 'Figure Skating' 'Football' 'Freestyle Skiing'
#  'Golf' 'Gymnastics' 'Handball' 'Hockey' 'Ice Hockey' 'Jeu De Paume'
#  'Judo' 'Lacrosse' 'Luge' 'Military Ski Patrol' 'Modern Pentathlon'
#  'Motorboating' 'Nordic Combined' 'Polo' 'Racquets' 'Rhythmic Gymnastics'
#  'Roque' 'Rowing' 'Rugby' 'Rugby Sevens' 'Sailing' 'Shooting'
#  'Short Track Speed Skating' 'Skeleton' 'Ski Jumping' 'Snowboarding'
#  'Softball' 'Speed Skating' 'Swimming' 'Synchronized Swimming'
#  'Table Tennis' 'Taekwondo' 'Tennis' 'Trampolining' 'Triathlon'
#  'Tug-Of-War' 'Volleyball' 'Water Polo' 'Weightlifting' 'Wrestling']
#                     ID
# Sport
# Aeronautics          1
# Alpine Skiing     8829
# ...

# %%
# 17)	Filtrer les lignes pour récupéer les athlètes ayant 
# dans leur nom « Owens » ou « Jesse » et stocker cela dans une nouvelle variable 

has_owens = data['Name'].str.contains(pat='Owens', case=False) ### LIKE '%Owens%'
has_jesse = data['Name'].str.contains(pat='Jesse', case=False)

## à voir en bonus les REGEX : expressions régulières

has_owens_jesse = data['Name'].str.contains(pat='(Owens|Jesse)', case=True)
# Out:
# C:\Users\cedri\AppData\Local\Temp\ipykernel_14416\3736334249.py:9: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   has_owens_jesse = data['Name'].str.contains(pat='(Owens|Jesse)', case=True)

# %%
has_jesse
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Name, Length: 271116, dtype: bool

# %%
owens_jesse = data.loc[has_owens | has_jesse, :] ### "& ==  and" ; "| == or" ; "~ == not"

print(owens_jesse.head(3))
display(owens_jesse.head(3))
# Out:
#           ID                         Name Sex   Age  Height  Weight  \
# 14038   7587   Kenneth Owens "Ken" Bantum   M  21.0   198.0   106.0
# 35531  18266  Jesse Landis "Lee" Carleton   M  41.0     NaN     NaN
# 35532  18266  Jesse Landis "Lee" Carleton   M  41.0     NaN     NaN
#
#                                    Team  NOC        Games  Year  Season  \
# 14038                     United States  USA  1956 Summer  1956  Summer
# 35531                     United States  USA  1904 Summer  1904  Summer
# 35532  United States Golf Association-3  USA  1904 Summer  1904  Summer
#
#             City      Sport                     Event   Medal
# 14038  Melbourne  Athletics  Athletics Men's Shot Put     NaN
# 35531  St. Louis       Golf     Golf Men's Individual     NaN
# 35532  St. Louis       Golf           Golf Men's Team  Bronze
#           ID                         Name Sex   Age  Height  Weight  \
# 14038   7587   Kenneth Owens "Ken" Bantum   M  21.0   198.0   106.0
# ...

# %%
# 18)	Compter les occurrences de la colonne 
#Event de Owens, Jesse (fonction values_counts())

# %%
owens_jesse.value_counts('Event').sum()
# Out:
# 101

# %%
owens_jesse['Event'].value_counts().sum()
# Out:
# 101

# %%
data.loc[has_owens_jesse,'Event'].count()
# Out:
# 98

# %%
# 19)	Compter y a-t-il de femme est d’homme dans le dataframe (fonction values_counts()) 

display(data.value_counts('Sex'))

data[['Sex','Name']].groupby('Sex').count()
# Out:
# Sex
# M    196594
# F     74522
# Name: count, dtype: int64
#        Name
# Sex
# F     74522
# M    196594

# %%
data['Sex'].value_counts()
# Out:
# Sex
# M    196594
# F     74522
# Name: count, dtype: int64

# %%
# 20)	Quel est l’athlète le plus jeune

data_age = data.sort_values('Age')
display(data_age.head(2))



con_plus_jeune = data['Age'] == data['Age'].min() # contruire la condition

#data[con_plus_jeune] # data.loc[con_plus_jeune,:]
data.loc[con_plus_jeune,["Name",'Age']]
# Out:
#             ID                Name Sex   Age  Height  Weight  \
# 142882   71691  Dimitrios Loundras   M  10.0     NaN     NaN
# 252231  126307        Liana Vicens   F  11.0   158.0    50.0
#
#                                  Team  NOC        Games  Year  Season  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer
# 252231                    Puerto Rico  PUR  1968 Summer  1968  Summer
#
#                City       Sport                                     Event  \
# 142882       Athina  Gymnastics     Gymnastics Men's Parallel Bars, Teams
# 252231  Mexico City    Swimming  Swimming Women's 200 metres Breaststroke
#
#          Medal
# 142882  Bronze
# 252231     NaN
#                       Name   Age
# 142882  Dimitrios Loundras  10.0

# %%
data.loc[data["Age"] == data['Age'].min(),:]
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
# 21)	Quel est l’athlète le plus vieux 

display(data_age.tail(1))

data_age.loc[data_age['Age'].isnull()==False,:].tail(1)
## --
display(data_age.dropna(subset=['Age']).tail(1))

display(data_age.loc[data['Age'].notnull()].tail(1))

## --
display(data_age[~data_age['Age'].isnull()].tail(1)) # ~ == not

display(data.loc[data["Age"] == data['Age'].max(),:])
display(data.loc[data["Age"] == np.max(data['Age'])])
# Out:
#             ID        Name Sex  Age  Height  Weight   Team  NOC        Games  \
# 270805  135435  Faelo Ziga   M  NaN     NaN     NaN  Chile  CHI  1928 Summer
#
#         Year  Season       City     Sport  \
# 270805  1928  Summer  Amsterdam  Swimming
#
#                                       Event Medal
# 270805  Swimming Men's 100 metres Freestyle   NaN
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
# ...

# %%
# data_age['Age'].dropna().tail(1) ### pas tout le data

# %%
# 22)	Quels sont les joueurs ayant gagné des médailles d’Or en badminton simple au cours des années. 
# Trier le résultat par ordre alphabétique sur le nom des joueurs.

# %%
is_badminton = data['Sport']=='Badminton'
got_golden = data['Medal'] == 'Gold'
contain_single = data['Event'].str.contains(pat='Single') #regex exemple: '[0-9]+'

# %%
def contains_single(x):
    """à définir"""
    if 'Single' in x:
        return True
    else:
        return False

    return 'Single' in x

contain_single_2 = data["Event"].map(contains_single)

# %%
print(np.sum(contain_single))
print(np.sum(is_badminton))
np.sum(got_golden)
# Out:
# 8081
# 1457
# 13372

# %%
(data
    .loc[is_badminton & got_golden & contain_single,:]
    .sort_values(by =['Year','Name',]
                 ,ascending =[False,True])
)
#.shape
# Out:
#             ID                                     Name Sex   Age  Height  \
# 149622   75045                  Carolina Mara Marn Marn   F  23.0   172.0
# 39337    20238                                Chen Long   M  27.0   188.0
# 138456   69540                                Li Xuerui   F  21.0   175.0
# 139312   69968                                  Lin Dan   M  28.0   177.0
# 139311   69968                                  Lin Dan   M  24.0   177.0
# 268881  134525                               Zhang Ning   F  33.0   175.0
# 95679    48435                           Taufik Hidayat   M  23.0   175.0
# 268880  134525                               Zhang Ning   F  29.0   175.0
# 81604    41427                             Gong Zhichao   F  23.0   163.0
# 108331   54755                               Ji Xinpeng   M  22.0   181.0
# 13855     7504                            Bang Su-Hyeon   F  23.0     NaN
# 99666    50431      Poul-Erik Hyer Larsen (-Engel Hyer)   M  30.0   188.0
# ...

# %%
#(data.loc[is_badminton & got_golden & contain_single,:].groupby('Name').sample())#.shape

# %%
# 23)	Quels sont les 3 pays ayant gagné le plus de médailles de 1984 à 2016 
years = (data['Year']>=1984) &  (data['Year'] <=2016)
cond_years = data['Year'].between(1984,2016)


GB = (data.loc[years,['NOC','Medal'] ## NOC=Name of Country
              ].groupby('NOC').count()
      
     ).sort_values(by='Medal',ascending=False)

# SELECT COUNT(Medal) as 'count medal', NOC
# FROM data
# WHERE year BETWEEN 1984 AND 2016
# GROUP BY NOC
# ORDER BY 'count medal' DESC
#

# %%
cond_years = data['Year'].between(1984,2016,inclusive='both')

# %%
GB.head(10)
# Out:
#      Medal
# NOC
# USA   2756
# GER   1268
# RUS   1148
# CHN    989
# AUS    976
# CAN    862
# ITA    704
# GBR    691
# FRA    683
# NED    612

# %%
has_medal = data['Medal'].notnull()
data.loc[years&has_medal].groupby('NOC').size().sort_values(ascending = False).head(3)
# Out:
# NOC
# USA    2756
# GER    1268
# RUS    1148
# dtype: int64

# %%
## pour constuire la condition du data (appliquer groupby après) 
data_years = data.set_index('Year').sort_index()
data_years.loc['1984':'2016'].head() # même chose que 'between...'
# Out:
#           ID                             Name Sex   Age  Height  Weight  \
# Year
# 1984  125085  Arnold Petrus Maria Vanderlijde   M  21.0   198.0    91.0
# 1984  104373                    Gisela Sailer   F  22.0   159.0    52.0
# 1984  121754                      John Treacy   M  27.0   175.0    59.0
# 1984  125130               Stojna Vangelovska   F  19.0   172.0    61.0
# 1984   19036          Martino "Matt" Catalano   M  26.0   188.0   102.0
#
#               Team  NOC        Games  Season         City       Sport  \
# Year
# 1984   Netherlands  NED  1984 Summer  Summer  Los Angeles      Boxing
# 1984  West Germany  FRG  1984 Summer  Summer  Los Angeles    Shooting
# 1984       Ireland  IRL  1984 Summer  Summer  Los Angeles   Athletics
# 1984    Yugoslavia  YUG  1984 Summer  Summer  Los Angeles  Basketball
# 1984        Canada  CAN  1984 Summer  Summer  Los Angeles   Athletics
#
#                                       Event   Medal
# Year
# ...

# %%
#24)	Combien y a-t-il d’homme et de femme ayant participé 
# aux Jeux olympiques d’été en 2016 
#cond_2016 = ete['Year']==2016

display(ete.loc[ete['Year']==2016,['Sex','Name']].groupby('Sex').count())

ete.loc[ete['Year']==2016,'Sex'].value_counts()
# Out:
#      Name
# Sex
# F    6223
# M    7465
# Sex
# M    7465
# F    6223
# Name: count, dtype: int64

# %%
# 25)	Afficher le nombre de médailles pour la Belgique 

is_belgian = data['Team']=='Belgium' # Belguim-1 exclu
is_belgian_2 = data['Team'].str.contains('Belgium') #indep exclu
is_belgian_3= data['NOC']=='BEL'

# %%
Q25 = data.loc[is_belgian_3,'Medal']#.dropna() #supprimer lignes vide

# %%
Q25.count()
# Out:
# 468

# %%
## les atlètes avec medaille
data.loc[is_belgian_3,['Medal', 'Name','Year']].dropna()
# Out:
#          Medal                               Name  Year
# 4877    Silver                   Alphonse Allaert  1920
# 4878      Gold                   Alphonse Allaert  1920
# 4879      Gold                   Alphonse Allaert  1920
# 8087      Gold  Henri Lucien Ernest Eugne Anspach  1912
# 8090    Bronze          Paul Eugne Albert Anspach  1908
# ...        ...                                ...   ...
# 263092  Bronze              Lode Alphonse Wouters  1948
# 263093    Gold              Lode Alphonse Wouters  1948
# 263607  Bronze            Gustave Marius L. Wuyts  1920
# 263638  Bronze                    Albert Wyckmans  1920
# 266971  Bronze           douard mile Gustave Yves  1948
#
# [468 rows x 3 columns]

# %% [markdown]
# # BONUS
#
# ### nombre de médailles par pays, ajouter nouvelle colonne: nbr_medailles

# %%
GB = data[['Medal','NOC', 'Name']].groupby('NOC').count()
print(type(GB))
GB_ = GB.sort_values('Medal',ascending=False).head(5)
display(GB_)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Medal   Name
# NOC
# USA   5637  18853
# URS   2503   5685
# GER   2165   9830
# GBR   2068  12256
# FRA   1777  12758

# %%
# GB_[GB_['NOC']=='USA'] ##erreur NOC pas en colonne
print(GB_.columns)
print(GB_.index)
# Out:
# Index(['Medal', 'Name'], dtype='object')
# Index(['USA', 'URS', 'GER', 'GBR', 'FRA'], dtype='object', name='NOC')

# %%
GB__ = GB_.reset_index()
display(GB__)
GB__.columns = ['NOC','Count_Medal', 'Count_Name']
display(GB__)
# Out:
#    NOC  Medal   Name
# 0  USA   5637  18853
# 1  URS   2503   5685
# 2  GER   2165   9830
# 3  GBR   2068  12256
# 4  FRA   1777  12758
#    NOC  Count_Medal  Count_Name
# 0  USA         5637       18853
# 1  URS         2503        5685
# 2  GER         2165        9830
# 3  GBR         2068       12256
# 4  FRA         1777       12758

# %%
GB__plus = GB__.copy()
GB__plus['ratio'] = GB__plus['Count_Medal']/GB__plus['Count_Name']

display(GB__plus)
# Out:
#    NOC  Count_Medal  Count_Name     ratio
# 0  USA         5637       18853  0.298998
# 1  URS         2503        5685  0.440281
# 2  GER         2165        9830  0.220244
# 3  GBR         2068       12256  0.168734
# 4  FRA         1777       12758  0.139285

# %% [markdown]
# ## groupby.agg()

# %%
GB1 = data[['Medal','NOC', 'Name', 'Age']].groupby('NOC').agg({'Medal':['count']
                                                        ,'Name':['count']
                                                        , 'Age':['count','mean']})

# %%
GB1
# Out:
#     Medal  Name   Age
#     count count count       mean
# NOC
# AFG     2   126    78  23.538462
# AHO     1    79    78  26.589744
# ALB     0    70    70  25.342857
# ALG    17   551   545  24.370642
# AND     0   169   169  23.065089
# ..    ...   ...   ...        ...
# YEM     0    32    32  21.093750
# YMD     0     5     5  23.600000
# YUG   390  2583  2454  24.745721
# ZAM     2   183   154  23.461039
# ZIM    22   311   309  25.200647
#
# [230 rows x 4 columns]

# %%
GB1.columns = ['Medal_count','Name_count','Age_count','Age_mean']
GB1
# Out:
#      Medal_count  Name_count  Age_count   Age_mean
# NOC
# AFG            2         126         78  23.538462
# AHO            1          79         78  26.589744
# ALB            0          70         70  25.342857
# ALG           17         551        545  24.370642
# AND            0         169        169  23.065089
# ..           ...         ...        ...        ...
# YEM            0          32         32  21.093750
# YMD            0           5          5  23.600000
# YUG          390        2583       2454  24.745721
# ZAM            2         183        154  23.461039
# ZIM           22         311        309  25.200647
#
# [230 rows x 4 columns]

# %% [markdown]
# ### .apply()

# %%
def myfunct(x):
    if x < 21:
        return 21
    elif x <22:
        return 22
    elif x <23:
        return 23
    elif x <24:
        return 24
    else:
        return 25

# %%
GB1['res_apply'] = GB1['Age_mean'].apply(myfunct)
GB1
# Out:
#      Medal_count  Name_count  Age_count   Age_mean  res_apply
# NOC
# AFG            2         126         78  23.538462         24
# AHO            1          79         78  26.589744         25
# ALB            0          70         70  25.342857         25
# ALG           17         551        545  24.370642         25
# AND            0         169        169  23.065089         24
# ..           ...         ...        ...        ...        ...
# YEM            0          32         32  21.093750         22
# YMD            0           5          5  23.600000         24
# YUG          390        2583       2454  24.745721         25
# ZAM            2         183        154  23.461039         24
# ZIM           22         311        309  25.200647         25
#
# [230 rows x 5 columns]

# %% [markdown]
# # END BONUS

# %%
#26)	Quels sont les sports pour lesquels la Belgique a des médailles d’Or 

display(data.loc[is_belgian_3&got_golden,'Sport'].unique())

data.loc[is_belgian_3&got_golden,['Sport','ID']].groupby('Sport').count().sort_values(by='ID',ascending=False)
# Out:
# array(['Archery', 'Fencing', 'Football', 'Figure Skating',
#        'Equestrianism', 'Sailing', 'Art Competitions', 'Weightlifting',
#        'Cycling', 'Swimming', 'Boxing', 'Athletics', 'Tennis', 'Shooting',
#        'Judo'], dtype=object)
#                   ID
# Sport
# Archery           35
# Football          14
# Cycling           13
# Fencing           10
# Equestrianism      7
# Athletics          4
# Sailing            4
# Art Competitions   2
# Figure Skating     2
# Judo               2
# Boxing             1
# Shooting           1
# Swimming           1
# Tennis             1
# Weightlifting      1

# %%
#27)	Quelles sont les années où la Belgique a remporté le plus de médailles 

GB = (data.loc[is_belgian_3,['Year','Medal']].groupby('Year').count())

# %%
GB.sort_values(by='Medal',ascending=False)
# Out:
#       Medal
# Year
# 1920    188
# 1924     44
# 1900     43
# 1908     33
# 1948     21
# 2016     21
# 1912     19
# 1936     14
# 1906     11
# 1976      9
# 1952      8
# 2000      7
# 1996      6
# 1928      6
# 1984      5
# 2008      5
# 1960      4
# 1968      3
# 1964      3
# 2012      3
# 1992      3
# 2004      3
# 1956      2
# 1988      2
# 1972      2
# 1932      1
# 1980      1
# 1998      1
# 2002      0
# 1994      0
# 2006      0
# 2010      0
# 2014      0

# %%
#28)	Afficher les médaillés d’Or féminin en Athlétisme. 
# Afficher le résultat Year, Event, Name, et Pays
is_female = data["Sex"]=='F'
#got_golden
is_athletics = data['Sport']=="Athletics"
cols= ['Year','Event','Name','Team']

# %%
np.sum(is_athletics)
# Out:
# 38624

# %%
data.loc[is_female & got_golden & is_athletics,cols]
# Out:
#         Year                                   Event  \
# 1527    2008              Athletics Women's Shot Put
# 1528    2012              Athletics Women's Shot Put
# 2815    1996             Athletics Women's Long Jump
# 3020    2016  Athletics Women's 4 x 100 metres Relay
# 6764    2000  Athletics Women's 4 x 400 metres Relay
# ...      ...                                     ...
# 268293  1972            Athletics Women's 400 metres
# 268294  1972  Athletics Women's 4 x 400 metres Relay
# 270104  1980  Athletics Women's 4 x 400 metres Relay
# 270970  2000          Athletics Women's Discus Throw
# 271076  1952              Athletics Women's Shot Put
#
#                                              Name           Team
# 1527         Valerie Kasanita Adams-Vili (-Price)    New Zealand
# 1528         Valerie Kasanita Adams-Vili (-Price)    New Zealand
# 2815                       Chioma Ajunwa (-Opara)        Nigeria
# 3020                            Morolake Akinosun  United States
# ...

# %%
#29)	Combien y a-t-il de sport par année 

data[['Year','Sport']].groupby('Year').nunique() # distinct count
# Out:
#       Sport
# Year
# 1896      9
# 1900     20
# 1904     18
# 1906     13
# 1908     24
# 1912     17
# 1920     25
# 1924     30
# 1928     25
# 1932     25
# 1936     32
# 1948     29
# 1952     27
# 1956     27
# 1960     27
# 1964     31
# 1968     30
# 1972     33
# 1976     33
# 1980     33
# 1984     35
# 1988     37
# 1992     41
# 1994     12
# 1996     31
# 1998     14
# 2000     34
# 2002     15
# 2004     34
# 2006     15
# 2008     34
# 2010     15
# 2012     32
# 2014     15
# 2016     34

# %%
# 30)	Quel est le top 15 des pays ayant le plus de médailles (toutes médailles confondues)
cond_where = data['ID'].notnull()
GB = data.loc[cond_where          ### séléction lignes: via slicing ou indexation Booléene
              ,['Medal','NOC']    ### colonnes : string (-> Series), liste (de string) (-> DataFrame)
             ].groupby('NOC').count()

#GB = data.groupby('NOC')[['Medal']].count()


GB.sort_values(by='Medal',ascending=False).head(15)
# Out:
#      Medal
# NOC
# USA   5637
# URS   2503
# GER   2165
# GBR   2068
# FRA   1777
# ITA   1637
# SWE   1536
# CAN   1352
# AUS   1320
# RUS   1165
# HUN   1135
# NED   1040
# NOR   1033
# GDR   1005
# CHN    989

# %%
cond_where
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 271111    True
# 271112    True
# 271113    True
# 271114    True
# 271115    True
# Name: ID, Length: 271116, dtype: bool

# %%
#31)	Quels sont les pays gagnant les plus médaillés par sport distinct

# %%
## table pivot = tableau croisé dynamique : 

df = data[['Medal','Year','ID']].copy()
display(df)
df.pivot_table(index = ['Year']
               , columns = ['Medal']
               , values = 'Medal'
               , aggfunc = 'count'
              )
# Out:
#        Medal  Year      ID
# 0        NaN  1992       1
# 1        NaN  2012       2
# 2        NaN  1920       3
# 3       Gold  1900       4
# 4        NaN  1988       5
# ...      ...   ...     ...
# 271111   NaN  1976  135569
# 271112   NaN  2014  135570
# 271113   NaN  2014  135570
# 271114   NaN  1998  135571
# 271115   NaN  2002  135571
#
# [271116 rows x 3 columns]
# Medal  Bronze  Gold  Silver
# Year
# 1896       38    62      43
# 1900      175   201     228
# 1904      150   173     163
# 1906      145   157     156
# 1908      256   294     281
# 1912      300   326     315
# 1920      367   493     448
# 1924      311   332     319
# 1928      281   275     267
# 1932      232   261     246
# 1936      330   348     347
# 1948      325   330     332
# 1952      347   351     335
# 1956      348   353     342
# 1960      357   359     342
# 1964      401   408     406
# 1968      421   425     410
# 1972      485   474     455
# 1976      518   508     505
# ...

# %%
PT = data.pivot_table(index=['NOC','Sport'],
                      columns=['Medal'], 
                      values='ID',
                      margins=True, 
                      aggfunc='count'
                     )
PT
#PT_ = PT.sort_values(by='All',ascending=False).reset_index()
#PT_
# Out:
# Medal           Bronze     Gold   Silver    All
# NOC Sport
# AFG Taekwondo      2.0      NaN      NaN      2
# AHO Sailing        NaN      NaN      1.0      1
# ALG Athletics      2.0      4.0      3.0      9
#     Boxing         5.0      1.0      NaN      6
#     Judo           1.0      NaN      1.0      2
# ...                ...      ...      ...    ...
# ZAM Athletics      NaN      NaN      1.0      1
#     Boxing         1.0      NaN      NaN      1
# ZIM Hockey         NaN     15.0      NaN     15
#     Swimming       1.0      2.0      4.0      7
# All            13295.0  13372.0  13116.0  39783
#
# [1450 rows x 4 columns]

# %%
PT_ = PT.sort_values(by='All',ascending=False).reset_index()
PT_
# Out:
# Medal  NOC      Sport   Bronze     Gold   Silver    All
# 0      All             13295.0  13372.0  13116.0  39783
# 1      USA  Athletics    221.0    542.0    317.0   1080
# 2      USA   Swimming    175.0    649.0    254.0   1078
# 3      AUS   Swimming    121.0    118.0    162.0    401
# 4      USA     Rowing     88.0    186.0    101.0    375
# ...    ...        ...      ...      ...      ...    ...
# 1445   JOR  Taekwondo      NaN      1.0      NaN      1
# 1446   JAM    Cycling      1.0      NaN      NaN      1
# 1447   TCH       Judo      1.0      NaN      NaN      1
# 1448   ITA     Tennis      1.0      NaN      NaN      1
# 1449   ISL       Judo      1.0      NaN      NaN      1
#
# [1450 rows x 6 columns]

# %%
### garder que les premier pays par sport

PT_.drop_duplicates(subset=['Sport']).head(20)
# Out:
# Medal  NOC                 Sport   Bronze     Gold   Silver    All
# 0      All                        13295.0  13372.0  13116.0  39783
# 1      USA             Athletics    221.0    542.0    317.0   1080
# 2      USA              Swimming    175.0    649.0    254.0   1078
# 4      USA                Rowing     88.0    186.0    101.0    375
# 5      ITA               Fencing     72.0    151.0    136.0    359
# 6      CAN            Ice Hockey     35.0    220.0     93.0    348
# 7      USA            Basketball     36.0    281.0     24.0    341
# 10     URS            Gymnastics     48.0    141.0     99.0    288
# 13     NED                Hockey     88.0     80.0     87.0    255
# 20     USA              Shooting     40.0    117.0     36.0    193
# 25     GBR               Cycling     55.0     59.0     68.0    182
# 29     HUN            Water Polo     36.0    107.0     29.0    172
# 32     NOR  Cross Country Skiing     37.0     54.0     73.0    164
# ...

# %%
GB = (data
      .loc[:,['NOC','Sport','Medal']]
      .groupby(['NOC','Sport'])
      .count()
      .sort_values(by=['Sport','Medal'],ascending=[True,False])
      .reset_index()
     )
GB
# Out:
#       NOC          Sport  Medal
# 0     SUI    Aeronautics      1
# 1     AUT  Alpine Skiing    114
# 2     SUI  Alpine Skiing     59
# 3     FRA  Alpine Skiing     45
# 4     USA  Alpine Skiing     44
# ...   ...            ...    ...
# 3996  VEN      Wrestling      0
# 3997  VIE      Wrestling      0
# 3998  YAR      Wrestling      0
# 3999  YEM      Wrestling      0
# 4000  ZAM      Wrestling      0
#
# [4001 rows x 3 columns]

# %%
GB.drop_duplicates(subset=['Sport']).head(15)
# Out:
#      NOC             Sport  Medal
# 0    SUI       Aeronautics      1
# 1    AUT     Alpine Skiing    114
# 102  GBR          Alpinism     12
# 108  KOR           Archery     69
# 206  GER  Art Competitions     26
# 257  USA         Athletics   1080
# 484  CHN         Badminton     64
# 553  CUB          Baseball    112
# 569  USA        Basketball    341
# 635  ESP     Basque Pelota      2
# 636  BRA  Beach Volleyball     26
# 677  GER          Biathlon     80
# 731  SUI         Bobsleigh     92
# 785  USA            Boxing    113
# 960  GER          Canoeing    163

# %% [raw]
# 32)	Quels étaient les pays les plus efficaces durant la guerre froide de 1952 à 1988 (i.e. le pays avec le plus de médailles par nombre d’athlètes envoyés)

# %%
in_cold_war = (data['Year'] >= 1952) & (data['Year'] <= 1988)

# %%
GB = data.loc[in_cold_war,['NOC','Name', 'Medal']].groupby('NOC').count()

# %%
GB.sort_values(by= 'Name',ascending=False)
# Out:
#      Name  Medal
# NOC
# USA  6244   1790
# URS  5685   2503
# GBR  4459    392
# ITA  3945    513
# CAN  3833    292
# ..    ...    ...
# ASA     6      0
# VIN     6      0
# YMD     5      0
# ALB     5      0
# NBO     2      0
#
# [176 rows x 2 columns]

# %%
GB['eff'] = GB['Medal']/GB['Name']
display(GB.sort_values(by= 'Medal',ascending=False).head(10))
display(GB.sort_values(by= ['eff','Medal'],ascending=False).head(10))
# Out:
#      Name  Medal       eff
# NOC
# URS  5685   2503  0.440281
# USA  6244   1790  0.286675
# GDR  2645   1005  0.379962
# HUN  2957    616  0.208319
# FRG  3315    586  0.176772
# ITA  3945    513  0.130038
# SWE  3201    417  0.130272
# ROU  2349    406  0.172840
# GBR  4459    392  0.087912
# AUS  3055    371  0.121440
#      Name  Medal       eff
# NOC
# URS  5685   2503  0.440281
# GDR  2645   1005  0.379962
# PAK   361    105  0.290859
# USA  6244   1790  0.286675
# WIF    20      5  0.250000
# HUN  2957    616  0.208319
# YUG  1901    359  0.188848
# FRG  3315    586  0.176772
# ROU  2349    406  0.172840
# IND   622    106  0.170418

# %% [markdown]
# # Selection Jesse

# %%
list_name_2 = data['Name'].str.contains(pat = 'Jesse ',case= True)
print(list_name_2.sum())

display(data.loc[list_name_2,'Name'].unique())
# Out:
# 41
# array(['Jesse Landis "Lee" Carleton', 'Jesse Cockney', 'Jesse Ellen Gey',
#        'John Jesse James', 'Jesse Kirkland', 'Benjamin Jesse D. Luckwell',
#        'Jesse Lumsden', 'Jesse Mahieu', 'Jesse William "John" Mashburn',
#        'Jesse Langford Montgomery', 'Jesse Parahi', 'Jesse Phillips',
#        'Jesse Reynolds Pike', 'Jesse Banard Renick', 'Jesse Ross',
#        'Jesse Prudente Ruz Flores', 'Jesse Harold Sergent',
#        'Jesse Aaron Smith', 'Jesse Jay Tamangrow', 'Jesse Teat',
#        'Jesse David Thielke', 'Jesse Vnnen', 'Jesse Alfred Wallingford',
#        'Jesse Daniel Williams', 'Harvey Jesse Wood'], dtype=object)

# %%
### creer la liste avec les partie de noms
list_name = (data['Name'].str.lower()).str.split(pat=" ")
list_name.head()
# Out:
# 0                    [a, dijiang]
# 1                     [a, lamusi]
# 2         [gunnar, nielsen, aaby]
# 3        [edgar, lindenau, aabye]
# 4    [christine, jacoba, aaftink]
# Name: Name, dtype: object

# %%
### def une fonction pour vérifier si une valeur est dans une liste
def has_value(x,val):
    '''x =  list_name; val = jesse'''
    if val in x:
        return True
    else:
        return False
    
    return val in x

# %%
### verifier si jesse est dans la liste des nom (par ligne)

temp = list_name.apply(has_value,args={'jesse'})
temp.sum()
# Out:
# 41

# %%
temp
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Name, Length: 271116, dtype: bool

# %%
data.loc[temp,:]
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 35531    18266    Jesse Landis "Lee" Carleton   M  41.0     NaN     NaN
# 35532    18266    Jesse Landis "Lee" Carleton   M  41.0     NaN     NaN
# 43016    22182                  Jesse Cockney   M  24.0   180.0    76.0
# 43017    22182                  Jesse Cockney   M  24.0   180.0    76.0
# 43018    22182                  Jesse Cockney   M  24.0   180.0    76.0
# 78615    39899                Jesse Ellen Gey   F  23.0   163.0    61.0
# 105746   53485               John Jesse James   M  27.0   183.0    75.0
# 119962   60736                 Jesse Kirkland   M  24.0     NaN     NaN
# 143573   72067     Benjamin Jesse D. Luckwell   M  22.0   186.0    75.0
# 143880   72225                  Jesse Lumsden   M  27.0   186.0   105.0
# 143881   72225                  Jesse Lumsden   M  27.0   186.0   105.0
# 143882   72225                  Jesse Lumsden   M  31.0   186.0   105.0
# ...

# %% [markdown]
# # Séléction Owens

# %%
list_name_2 = data['Name'].str.contains(pat = 'Owens',case= False)
print(list_name_2.sum())

display(data.loc[list_name_2,'Name'].unique())
# Out:
# 25
# array(['Kenneth Owens "Ken" Bantum', 'Alexander Mah Owens Drysdale',
#        'Kathlyn "Kathy" Kelley (-Owens)', 'Claude Lowenstein',
#        'Sophie Rowens Muir', 'Gerald "Ger" Owens', 'James Earl Owens',
#        'Jenny Owens', 'James Cleveland "Jesse" Owens', 'Tarja Owens',
#        'Thomas Alfred Owens'], dtype=object)

# %%
list_name = (data['Name'].str.lower()).str.replace('[-\(\)]','',regex=True).str.split(pat=" ")

display(list_name.head())

temp = list_name.apply(has_value,args={'owens'})
print('-'*5)
temp.sum()
# Out:
# 0                    [a, dijiang]
# 1                     [a, lamusi]
# 2         [gunnar, nielsen, aaby]
# 3        [edgar, lindenau, aabye]
# 4    [christine, jacoba, aaftink]
# Name: Name, dtype: object
# -----
# 22

# %%
data.loc[temp,'Name'].unique()
# Out:
# array(['Kenneth Owens "Ken" Bantum', 'Alexander Mah Owens Drysdale',
#        'Kathlyn "Kathy" Kelley (-Owens)', 'Gerald "Ger" Owens',
#        'James Earl Owens', 'Jenny Owens', 'James Cleveland "Jesse" Owens',
#        'Tarja Owens', 'Thomas Alfred Owens'], dtype=object)

# %%
list_name[temp]
# Out:
# 14038        [kenneth, owens, "ken", bantum]
# 58932      [alexander, mah, owens, drysdale]
# 58933      [alexander, mah, owens, drysdale]
# 58934      [alexander, mah, owens, drysdale]
# 58935      [alexander, mah, owens, drysdale]
# 115552     [kathlyn, "kathy", kelley, owens]
# 179547                [gerald, "ger", owens]
# 179548                [gerald, "ger", owens]
# 179549                [gerald, "ger", owens]
# 179550                  [james, earl, owens]
# 179551                        [jenny, owens]
# 179552                        [jenny, owens]
# 179553                        [jenny, owens]
# 179554                        [jenny, owens]
# 179555                        [jenny, owens]
# 179556                        [jenny, owens]
# 179557    [james, cleveland, "jesse", owens]
# 179558    [james, cleveland, "jesse", owens]
# 179559    [james, cleveland, "jesse", owens]
# 179560    [james, cleveland, "jesse", owens]
# 179561                        [tarja, owens]
# ...

# %% [markdown]
# # Regex
# regular expression
# https://docs.python.org/3/library/re.html

# %%
patern = '[0-9]+' ### toutes les valeurs de 0 à 9 et/ou combinaison '+' de ceux-ci

### toutes les équipes avec des chiffres dans leur nom 
list_num = data['Team'].astype(str).str.contains(pat= patern,regex=True)

data.loc[list_num,:]
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 268        139        George "Ioannis" Abbot   M   NaN     NaN     NaN
# 626        363                    Kazumi Abe   M  24.0   178.0    67.0
# 627        363                    Kazumi Abe   M  24.0   178.0    67.0
# 628        363                    Kazumi Abe   M  28.0   178.0    67.0
# 778        448                 Sarah Abitbol   F  22.0   150.0    43.0
# ...        ...                           ...  ..   ...     ...     ...
# 270610  135343    Aleksandr Yuryevich Zubkov   M  39.0   189.0   102.0
# 270791  135424                Nadine Zumkehr   F  31.0   172.0    64.0
# 270987  135508      Vera Igorevna Zvonaryova   F  23.0   172.0    59.0
# 271104  135564  Yevgeny Aleksandrovich Zykov   M  22.0   172.0    65.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %% [markdown]
# # .info cusom:

# %%
def INFO(data):
    res = pd.concat([
        data.dtypes
        ,data.isnull().sum()
        ,data.nunique()
    ],axis=1)
    res.columns = ['dtype','isnull_sum','nunique']
    
    return res

# %%
INFO(data)
# Out:
#           dtype  isnull_sum  nunique
# ID        int64           0   135571
# Name     object           0   134732
# Sex      object           0        2
# Age     float64        9474       74
# Height  float64       60171       95
# Weight  float64       62875      220
# Team     object           0     1184
# NOC      object           0      230
# Games    object           0       51
# Year      int64           0       35
# Season   object           0        2
# City     object           0       42
# Sport    object           0       66
# Event    object           0      765
# Medal    object      231333        3
