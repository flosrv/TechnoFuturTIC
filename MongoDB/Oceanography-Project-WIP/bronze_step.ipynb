# %%
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from imports import *
from functions import *

# %% [markdown]
# Initialize PostgreSQL Connection

# %%
path_postgresql_creds = r"C:\Users\f.gionnane\Documents\Data Engineering\Credentials\postgresql_creds.json"

with open(path_postgresql_creds, 'r') as file:
    content = json.load(file)
    user = content["user"]
    password = content["password"]
    host = content["host"]
    port = content["port"]

db = "Oceanography_ML_Project"
schema = "Bronze"

# Créer l'engine PostgreSQL
engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}")
conn = engine.connect()

# %% [markdown]
# Get Available Stations ID List
#
# Filter Dysfunctional Stations

# %%
# get all stations and some metadata as a Pandas DataFrame
stations_df = api.stations()
# parse the response as a dictionary
stations_df = api.stations(as_df=True)

print(len(stations_df))
# Out:
# 146

# %%
access_error_url_list = []

# Liste de mots à rechercher dans la colonne "Remark"
blacklist = ["Failure", "ceased", "failed", "recovered", "stopped", 'adrift']
stations_id_set = set()

print(f'Avant Filtre: {stations_df.shape[0]}')

# Liste pour collecter les indices à supprimer
indices_a_supprimer = []

# Parcours des lignes de la DataFrame
for idx, row in stations_df.iterrows():
    station_id = row["Station"]
    station_Location = row["Hull No./Config and Location"]  # Extraire la valeur de la cellule pour chaque ligne
    
    # Extraction du nom de la station si un ")" est trouvé
    if ")" in station_Location:
        station_name = station_Location.split(')')[1].rstrip(" )")  # On enlève l'espace et la parenthèse en fin de chaîne
    else:
        station_name = station_Location.strip()  # Si pas de ")", on garde toute la chaîne

    station_name = station_name.rstrip(" )").replace("(", "").replace(")", "").strip()

    # Nettoyage final pour enlever toute parenthèse ou espace en fin de nom
    station_name = station_name.rstrip(" )")

    # Vérifier si "Remark" n'est pas NaN et si un des éléments de blacklist est dans "Remark"
    if isinstance(row["Remark"], str) and any(blacklist_word.lower() in row["Remark"].lower() for blacklist_word in blacklist):
        # Ajouter l'index à la liste
        indices_a_supprimer.append(idx)
    else:
        try:
            # Effectuer l'appel API
            buoy_data = NDBC.realtime_observations(station_id)
            
            # Vérifier si les données de l'API sont valides (si le DataFrame n'est pas vide)
            if not buoy_data.empty:
                print(f'Buoy {station_id}: {station_name} passed the Remarks and API Test!')
                stations_id_set.add(station_id)
            else:
                print(f'Buoy {station_id}: {station_name} did not return valid data. Deleting.')
                indices_a_supprimer.append(idx)

        except Exception as e:
            # Si l'erreur est un HTTPError, on peut essayer d'afficher le code d'erreur
            if isinstance(e, HTTPError):
                print(f'Buoy {station_id}: {station_name} API Call returned {e.code}. Deleting.')
            else:
                # Dans tous les autres cas d'exception, on affiche le message d'erreur complet
                print(f'Buoy {station_id}: {station_name} API Call encountered an error. Deleting.')
                
                if str(e).startswith("Error accessing"):
                    url = f"https://www.ndbc.noaa.gov/station_page.php?station={station_id}"
                    access_error_url_list.append([station_id, url])
            # Ajouter l'index à la liste en cas d'erreur
            indices_a_supprimer.append(idx)

# Supprimer les lignes après la boucle
stations_df.drop(index=indices_a_supprimer, inplace=True)

print(f'Après Filtre: {stations_df.shape[0]}')
# Out:
# Avant Filtre: 146
# Buoy 41004: Edisto passed the Remarks and API Test!
# Buoy 41008: Grays Reef passed the Remarks and API Test!
# Buoy 41010: Canaveral East passed the Remarks and API Test!
# Buoy 41013: Frying Pan Shoals, Nc buoy passed the Remarks and API Test!
# Buoy 41040: North Equatorial One passed the Remarks and API Test!
# Buoy 41043: Ne Puerto Rico passed the Remarks and API Test!
# Buoy 41044: Ne St Martin passed the Remarks and API Test!
# Buoy 41049: South Bermuda passed the Remarks and API Test!
# Buoy 42001: Mid Gulf passed the Remarks and API Test!
# Buoy 42002: West Gulf passed the Remarks and API Test!
# Buoy 42003: East Gulf API Call encountered an error. Deleting.
# Buoy 42012: Orange Beach, Al passed the Remarks and API Test!
# Buoy 42019: Freeport, Tx passed the Remarks and API Test!
# Buoy 42020: Corpus Christi, Tx passed the Remarks and API Test!
# Buoy 42035: Galveston, Tx passed the Remarks and API Test!
# Buoy 42036: West Tampa passed the Remarks and API Test!
# Buoy 42056: Yucatan Basin passed the Remarks and API Test!
# Buoy 42058: Central Caribbean passed the Remarks and API Test!
# Buoy 42060: Caribbean Valley passed the Remarks and API Test!
# Buoy 44007: Portland, Me passed the Remarks and API Test!
# Buoy 44009: Delaware Bay passed the Remarks and API Test!
# Buoy 44011: Georges Bank passed the Remarks and API Test!
# Buoy 44013: Boston passed the Remarks and API Test!
# Buoy 44014: Virginia Beach passed the Remarks and API Test!
# Buoy 44020: Nantucket Sound passed the Remarks and API Test!
# Buoy 44025: Long Island passed the Remarks and API Test!
# Buoy 44027: Jonesport, Me passed the Remarks and API Test!
# Buoy 44065: New York Harbor Entrance passed the Remarks and API Test!
# Buoy 46001: Western Gulf Of Alaska passed the Remarks and API Test!
# Buoy 46006: Southeast Papa passed the Remarks and API Test!
# Buoy 46014: Pt Arena passed the Remarks and API Test!
# Buoy 46022: Eel River passed the Remarks and API Test!
# Buoy 46025: Santa Monica Basin passed the Remarks and API Test!
# Buoy 46027: St Georges passed the Remarks and API Test!
# Buoy 46029: Columbia River Bar passed the Remarks and API Test!
# Buoy 46053: East Santa Barb passed the Remarks and API Test!
# Buoy 46069: South Santa Rosa Is passed the Remarks and API Test!
# Buoy 46071: Western Aleutians passed the Remarks and API Test!
# Buoy 46072: Central Aleutians passed the Remarks and API Test!
# Buoy 46078: Albatross Bank passed the Remarks and API Test!
# Buoy 46084: Cape Edgecumbe passed the Remarks and API Test!
# Buoy 46086: San Clemente Basin passed the Remarks and API Test!
# Buoy 46087: Neah Bay, Wa passed the Remarks and API Test!
# Buoy 46088: New Dungeness, Wa passed the Remarks and API Test!
# Buoy 51000: Northern Hawaii One passed the Remarks and API Test!
# Buoy 51001: Northwestern Hawaii One passed the Remarks and API Test!
# Buoy 51002: Southwestern Hawaii passed the Remarks and API Test!
# Buoy AMAA2: East Amatuli Island Light passed the Remarks and API Test!
# Buoy BURL1: Southwest Pass , La passed the Remarks and API Test!
# Buoy DBLN6: Dunkirk, Ny passed the Remarks and API Test!
# Buoy DISW3: Devils Island, Wi passed the Remarks and API Test!
# Buoy FFIA2: Five Fingers ,ak passed the Remarks and API Test!
# Buoy FILA2: Flat Island Light passed the Remarks and API Test!
# Buoy IOSN3: Isle Of Shoals, Nh passed the Remarks and API Test!
# Buoy KTNF1: Keaton Beach, Fl API Call encountered an error. Deleting.
# Buoy LONF1: Long Key, Fl passed the Remarks and API Test!
# Buoy MDRM1: Mt Desert Rock, Me passed the Remarks and API Test!
# Buoy MRKA2: Middle Rock Light, Ak passed the Remarks and API Test!
# Buoy POTA2: Potato Point, Ak passed the Remarks and API Test!
# Buoy PTGC1: Point Arguello, Ca API Call encountered an error. Deleting.
# Buoy ROAM4: Rock Of Ages, Mi passed the Remarks and API Test!
# Buoy SANF1: Sand Key, Fl passed the Remarks and API Test!
# Buoy SBIO1: South Bass Island, Oh passed the Remarks and API Test!
# Buoy SISW1: Smith Island, Wa passed the Remarks and API Test!
# Buoy SMKF1: Sombrero Key, Fl API Call encountered an error. Deleting.
# Buoy WPOW1: West Point, Wa passed the Remarks and API Test!
# Après Filtre: 39

# %%
for item in access_error_url_list:
    print(f"Access error for buoy {item[0]}")
    print(f"{item[1]}\n")
# Out:
# Access error for buoy 42003
# https://www.ndbc.noaa.gov/station_page.php?station=42003
#
# Access error for buoy KTNF1
# https://www.ndbc.noaa.gov/station_page.php?station=KTNF1
#
# Access error for buoy PTGC1
# https://www.ndbc.noaa.gov/station_page.php?station=PTGC1
#
# Access error for buoy SMKF1
# https://www.ndbc.noaa.gov/station_page.php?station=SMKF1

# %% [markdown]
# Testing get_station_metadata and parse_buoy_json Functions

# %%
# Parcourir les lignes du DataFrame
for idx, row in stations_df.iterrows():
    station_id_from_df = row["Station"]  # Renommer la variable ici
    metadata = get_station_metadata(station_id_from_df)
    print(f"Metadata pour la station {station_id_from_df}: {metadata}")  # Vérification de la valeur de metadata
    Name = metadata["Name"]
    # Changer le nom de la variable retournée par parse_buoy_json
    parsed_station_id, station_zone, lat_buoy, lon_buoy = parse_buoy_json(metadata)
# Out:
# Metadata pour la station 41008: {'Watch circle radius': '69 yards', 'Water depth': '16 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '31.400 N 80.866 W (31°24\'0" N 80°51\'59" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 41008 (LLNR 833) - GRAYS REEF - 40 NM Southeast of Savannah, GA'}
# Metadata pour la station 41044: {'Watch circle radius': '5441 yards', 'Water depth': '5419 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '21.582 N 58.630 W (21°34\'57" N 58°37\'48" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 41044  - NE ST MARTIN - 330 NM NE St Martin Is'}
# Metadata pour la station 42001: {'Watch circle radius': '3238 yards', 'Water depth': '3200 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '25.926 N 89.662 W (25°55\'32" N 89°39\'43" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 42001 (LLNR 1465) - MID GULF - 180 nm South of Southwest Pass, LA'}
# Metadata pour la station 42002: {'Watch circle radius': '3138 yards', 'Water depth': '3208 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '25.950 N 93.780 W (25°57\'0" N 93°46\'48" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 42002 (LLNR 1470) - WEST GULF - 207 NM East of Brownsville, TX'}
# Metadata pour la station 42012: {'Watch circle radius': '74 yards', 'Water depth': '23.5 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '30.060 N 87.548 W (30°3\'36" N 87°32\'54" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 42012 (LLNR 138) - ORANGE BEACH - 44 NM SE of Mobile, AL'}
# Metadata pour la station 42036: {'Watch circle radius': '130 yards', 'Water depth': '53.3 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '28.500 N 84.505 W (28°30\'0" N 84°30\'18" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 42036 (LLNR 855) - WEST TAMPA  - 112 NM WNW of Tampa, FL'}
# Metadata pour la station 42056: {'Watch circle radius': '4502 yards', 'Water depth': '4578 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '19.820 N 84.980 W (19°49\'12" N 84°58\'48" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 42056 (LLNR 80) - Yucatan Basin - 120 NM ESE of Cozumel, MX'}
# Metadata pour la station 42058: {'Watch circle radius': '4123 yards', 'Water depth': '4136 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '14.512 N 75.153 W (14°30\'43" N 75°9\'11" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 42058  - Central Caribbean - 210 NM SSE of Kingston, Jamaica'}
# Metadata pour la station 44020: {'Watch circle radius': '46 yards', 'Water depth': '16.5 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '41.497 N 70.283 W (41°29\'50" N 70°16\'59" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 44020 (LLNR 13700) - NANTUCKET SOUND'}
# Metadata pour la station 44025: {'Watch circle radius': '83 yards', 'Water depth': '40.2 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '40.258 N 73.175 W (40°15\'30" N 73°10\'29" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 44025 (LLNR 830) - LONG ISLAND - 30 NM South of Islip, NY'}
# Metadata pour la station 44027: {'Watch circle radius': '308 yards', 'Water depth': '188 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '44.284 N 67.301 W (44°17\'2" N 67°18\'4" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 44027 (LLNR 4) - Jonesport, ME - 20 NM SE of Jonesport, ME'}
# Metadata pour la station 44065: {'Watch circle radius': '60 yards', 'Water depth': '26 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '40.368 N 73.701 W (40°22\'6" N 73°42\'2" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 44065 (LLNR 725) - New York Harbor Entrance - 15 NM SE of Breezy Point , NY'}
# Metadata pour la station 46001: {'Watch circle radius': '4212 yards', 'Water depth': '4123 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '56.296 N 148.027 W (56°17\'46" N 148°1\'37" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 46001 (LLNR 984) - WESTERN GULF OF ALASKA  - 175NM SE of Kodiak, AK'}
# Metadata pour la station 46006: {'Watch circle radius': '4530 yards', 'Water depth': '4347 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '40.764 N 137.377 W (40°45\'52" N 137°22\'37" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 46006 (LLNR 510) - SOUTHEAST PAPA - 600NM West of Eureka, CA'}
# Metadata pour la station 46014: {'Watch circle radius': '588 yards', 'Water depth': '335 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '39.225 N 123.980 W (39°13\'29" N 123°58\'47" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46014 (LLNR 445) - PT ARENA - 19NM North of Point Arena, CA'}
# Metadata pour la station 46022: {'Watch circle radius': '652 yards', 'Water depth': '456 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '3.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '40.716 N 124.540 W (40°42\'58" N 124°32\'24" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46022 (LLNR 500) - EEL RIVER - 17NM WSW of Eureka, CA'}
# Metadata pour la station 46025: {'Watch circle radius': '1291 yards', 'Water depth': '890 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '33.755 N 119.045 W (33°45\'19" N 119°2\'42" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46025 (LLNR 181) - Santa Monica Basin - 33NM WSW of Santa Monica, CA'}
# Metadata pour la station 46027: {'Watch circle radius': '136 yards', 'Water depth': '60 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '41.840 N 124.382 W (41°50\'24" N 124°22\'54" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46027 (LLNR 562) - ST GEORGES - 8 NM NW of Crescent City, CA'}
# Metadata pour la station 46029: {'Watch circle radius': '233 yards', 'Water depth': '131 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '46.163 N 124.487 W (46°9\'48" N 124°29\'12" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46029 (LLNR 688) - COLUMBIA RIVER BAR - 20NM West of Columbia River Mouth'}
# Metadata pour la station 46053: {'Watch circle radius': '685 yards', 'Water depth': '405 m', 'Sea temp depth': '1.1 m below water line', 'Barometer elevation': '1.8 m above mean sea level', 'Anemometer height': '3.2 m above site elevation', 'Air temp height': '2.8 m above site elevation', 'Site elevation': 'sea level', 'Location': '34.241 N 119.839 W (34°14\'26" N 119°50\'20" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 2.1-meter ionomer foam buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46053 (LLNR 196) - EAST SANTA BARBARA  - 12NM Southwest of Santa Barbara, CA'}
# Metadata pour la station 46069: {'Watch circle radius': '945 yards', 'Water depth': '977.8 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '33.677 N 120.213 W (33°40\'38" N 120°12\'46" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46069 (LLNR 181.6) - SOUTH SANTA ROSA - 14 NM SW of Santa Rosa Island, CA'}
# Metadata pour la station 46071: {'Watch circle radius': '4155 yards', 'Water depth': '3967 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '51.040 N 179.764 E (51°2\'24" N 179°45\'50" E)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46071 (LLNR 27545) - WESTERN ALEUTIANS - 14NM SOUTH OF AMCHITKA IS, AK'}
# Metadata pour la station 46072: {'Watch circle radius': '3629 yards', 'Water depth': '3589 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '51.645 N 172.145 W (51°38\'42" N 172°8\'42" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 46072 (LLNR 27510) - CENTRAL ALEUTIANS 230 NM SW Dutch Harbor'}
# Metadata pour la station 46078: {'Watch circle radius': '5515 yards', 'Water depth': '5361 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '55.561 N 152.599 W (55°33\'38" N 152°35\'56" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46078 (LLNR 1187) - ALBATROSS BANK - 104NM South of Kodiak Is., AK'}
# Metadata pour la station 46084: {'Watch circle radius': '1212 yards', 'Water depth': '1149 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '56.614 N 136.040 W (56°36\'51" N 136°2\'24" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46084 (LLNR 1028) - CAPE EDGECUMBE - 25NM SSW of Cape Edgecumbe, AK'}
# Metadata pour la station 46086: {'Watch circle radius': '1889 yards', 'Water depth': '1844.7 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '32.499 N 118.052 W (32°29\'55" N 118°3\'9" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy w/ seal cage, SCOOP payload', 'Name': 'Station 46086 (LLNR 81) - SAN CLEMENTE BASIN - 27NM SE Of San Clemente Is, CA'}
# Metadata pour la station 46087: {'Watch circle radius': '212 yards', 'Water depth': '262.4 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '48.493 N 124.727 W (48°29\'36" N 124°43\'38" W)', 'Statation Type': 'Funding provided by the United States Coast GuardOwned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 46087 (LLNR 756) - Neah Bay - 6 NM North of Cape Flattery, WA (Traffic Separation Lighted Buoy)'}
# Metadata pour la station 46088: {'Watch circle radius': '161 yards', 'Water depth': '115.5 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '48.332 N 123.179 W (48°19\'56" N 123°10\'44" W)', 'Statation Type': 'Funding provided by the United States Coast GuardOwned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 46088 (LLNR 16337) - NEW DUNGENESS - 17 NM NE of Port Angeles, WA'}
# Metadata pour la station 51000: {'Watch circle radius': '4932 yards', 'Water depth': '4762 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '23.528 N 153.792 W (23°31\'42" N 153°47\'30" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 51000 (LLNR 28005.9) - NORTHERN HAWAII ONE - 245NM NE of Honolulu HI'}
# Metadata pour la station 51001: {'Watch circle radius': '5007 yards', 'Water depth': '4895 m', 'Sea temp depth': '1.1 m below water line', 'Barometer elevation': '1.8 m above mean sea level', 'Anemometer height': '3.2 m above site elevation', 'Air temp height': '2.8 m above site elevation', 'Location': '24.475 N 162.030 W (24°28\'30" N 162°1\'48" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 2.1-meter ionomer foam buoy, SCOOP payload', 'Name': 'Station 51001 (LLNR 28006) - NORTHWESTERN HAWAII ONE - 188 NM NW of Kauai Island, HI'}
# Metadata pour la station 51002: {'Watch circle radius': '5029 yards', 'Water depth': '4979 m', 'Sea temp depth': '1.5 m below water line', 'Barometer elevation': '2.7 m above mean sea level', 'Anemometer height': '4.1 m above site elevation', 'Air temp height': '3.7 m above site elevation', 'Site elevation': 'sea level', 'Location': '17.070 N 157.755 W (17°4\'12" N 157°45\'18" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter foam buoy, SCOOP payload', 'Name': 'Station 51002 (LLNR 28005.1) - SOUTHWEST HAWAII - 215NM SSW of Hilo, HI'}
# Metadata pour la station BURL1: {'Barometer elevation': '13.4 m above mean sea level', 'Anemometer height': '38 m above site elevation', 'Air temp height': '13.7 m above site elevation', 'Site elevation': '0 m above mean sea level', 'Location': '28.906 N 89.429 W (28°54\'22" N 89°25\'43" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, ARES payload', 'Name': 'Station BURL1  - Southwest Pass, LA'}
# Metadata pour la station FFIA2: {'Barometer elevation': '21.3 m above mean sea level', 'Anemometer height': '22 m above site elevation', 'Air temp height': '4.3 m above site elevation', 'Site elevation': '6.7 m above mean sea level', 'Location': '57.272 N 133.630 W (57°16\'18" N 133°37\'48" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, Sutron XPERT payload', 'Name': 'Station FFIA2  - Five Fingers, AK'}
# Metadata pour la station LONF1: {'Barometer elevation': '5.03 m above mean sea level', 'Anemometer height': '6.34 m above site elevation', 'Air temp height': '6.1 m above site elevation', 'Site elevation': '0 m above mean sea level', 'Location': '24.844 N 80.864 W (24°50\'39" N 80°51\'49" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, SCOOP payload', 'Name': 'Station LONF1  - Long Key, FL'}
# Metadata pour la station MDRM1: {'Barometer elevation': '16.5 m above mean sea level', 'Anemometer height': '22.6 m above site elevation', 'Air temp height': '15.2 m above site elevation', 'Site elevation': '9.1 m above mean sea level', 'Location': '43.969 N 68.128 W (43°58\'7" N 68°7\'42" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, MARS payload', 'Name': 'Station MDRM1  - Mt. Desert Rock, ME'}
# Metadata pour la station MRKA2: {'Barometer elevation': '10.9 m above mean sea level', 'Anemometer height': '15.9 m above site elevation', 'Air temp height': '15.4 m above site elevation', 'Site elevation': '0 m above mean sea level', 'Location': '61.082 N 146.662 W (61°4\'54" N 146°39\'42" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, Sutron XPERT payload', 'Name': 'Station MRKA2  - Middle Rock Light, AK'}
# Metadata pour la station POTA2: {'Barometer elevation': '8.5 m above mean sea level', 'Anemometer height': '10 m above site elevation', 'Air temp height': '9.1 m above site elevation', 'Site elevation': '7 m above mean sea level', 'Location': '61.060 N 146.700 W (61°3\'36" N 146°42\'0" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, Sutron XPERT payload', 'Name': 'Station POTA2  - Potato Point, AK'}
# Metadata pour la station SANF1: {'Barometer elevation': '13.6 m above mean sea level', 'Anemometer height': '14.8 m above site elevation', 'Air temp height': '14.6 m above site elevation', 'Site elevation': '0 m above mean sea level', 'Location': '24.456 N 81.877 W (24°27\'21" N 81°52\'38" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, SCOOP payload', 'Name': 'Station SANF1  - Sand Key, FL'}
# Metadata pour la station SBIO1: {'Barometer elevation': '178.4 m above mean sea level', 'Anemometer height': '24.3 m above site elevation', 'Air temp height': '23.4 m above site elevation', 'Site elevation': '176.8 m above mean sea level', 'Location': '41.629 N 82.841 W (41°37\'44" N 82°50\'29" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, C-MAN Station, Sutron XPERT payload', 'Name': 'Station SBIO1  - South Bass Island, OH'}

# %%
for key, value in metadata.items():
    print(key)
# Out:
# Barometer elevation
# Anemometer height
# Air temp height
# Site elevation
# Location
# Statation Type
# Name

# %%
# list_check=[]

# stations_sans_zone = [
#     "44020",
#     "46072",
#     "BURL1",
#     "FFIA2",
#     "LONF1",
#     "MDRM1",
#     "MRKA2",
#     "POTA2",
#     "SANF1",
#     "SBIO1"
# ]

# # Parcourir les lignes du DataFrame
# for id in stations_sans_zone:
#     metadata = get_station_metadata(id)
#     Name = metadata["Name"]

#     station_id, station_zone, lat_buoy, lon_buoy, marine_data_table_name = parse_buoy_json(metadata)
#     message = f"Station {station_id}: \nNom: {Name}\nZone: {station_zone}"
#     list_check.append(message)

# for msg in list_check:
#     print(f"{msg}\n")

# %% [markdown]
# Build Dictionary of Stations

# %%
# Dictionnaire pour stocker les DataFrames, clé : ID de la bouée, valeur : DataFrame
buoy_datas = {}
buoy_list = []

# Parcours de chaque bouée dans stations_df
for index, row in stations_df.iterrows():
    buoy_id = row['Station']

    metadata = get_station_metadata(buoy_id)  # Utilise buoy_id au lieu de station_id_from_df
    # Changer le nom de la variable retournée par parse_buoy_json
    parsed_station_id, station_zone, lat_buoy, lon_buoy = parse_buoy_json(metadata)

    # Initialiser le dictionnaire pour chaque bouée s'il n'est pas encore créé
    if buoy_id not in buoy_datas:
        buoy_datas[buoy_id] = {}

    # Ajouter les informations de la bouée
    buoy_datas[buoy_id]["Zone"] = station_zone
    buoy_datas[buoy_id]["Lat"] = lat_buoy
    buoy_datas[buoy_id]["Lon"] = lon_buoy

    # Ajouter la bouée à la liste
    buoy_list.append(buoy_id)

# Affichage du nombre de bouées réussies et échouées
print(f"Nombre de bouées traitées : {len(buoy_datas)}\n")

# Afficher le contenu de buoy_datas
buoy_datas
# Out:
# Nombre de bouées traitées : 39
# {'41008': {'Zone': 'grays reef', 'Lat': '31.40N', 'Lon': '80.87W'},
#  '41044': {'Zone': 'ne st martin', 'Lat': '21.58N', 'Lon': '58.63W'},
#  '42001': {'Zone': 'mid gulf', 'Lat': '25.93N', 'Lon': '89.66W'},
#  '42002': {'Zone': 'west gulf', 'Lat': '25.95N', 'Lon': '93.78W'},
#  '42012': {'Zone': 'orange beach', 'Lat': '30.06N', 'Lon': '87.55W'},
#  '42036': {'Zone': 'west tampa', 'Lat': '28.50N', 'Lon': '84.50W'},
#  '42056': {'Zone': 'yucatan basin', 'Lat': '19.82N', 'Lon': '84.98W'},
#  '42058': {'Zone': 'central caribbean', 'Lat': '14.51N', 'Lon': '75.15W'},
#  '44020': {'Zone': 'nantucket sound', 'Lat': '41.50N', 'Lon': '70.28W'},
#  '44025': {'Zone': 'long island', 'Lat': '40.26N', 'Lon': '73.17W'},
#  '44027': {'Zone': 'jonesport, me', 'Lat': '44.28N', 'Lon': '67.30W'},
#  '44065': {'Zone': 'new york harbor entrance',
#   'Lat': '40.37N',
#   'Lon': '73.70W'},
#  '46001': {'Zone': 'western gulf of alaska',
#   'Lat': '56.30N',
#   'Lon': '148.03W'},
#  '46006': {'Zone': 'southeast papa', 'Lat': '40.76N', 'Lon': '137.38W'},
#  '46014': {'Zone': 'pt arena', 'Lat': '39.23N', 'Lon': '123.98W'},
#  '46022': {'Zone': 'eel river', 'Lat': '40.72N', 'Lon': '124.54W'},
#  '46025': {'Zone': 'santa monica basin', 'Lat': '33.76N', 'Lon': '119.05W'},
#  '46027': {'Zone': 'st georges', 'Lat': '41.84N', 'Lon': '124.38W'},
#  '46029': {'Zone': 'columbia river bar', 'Lat': '46.16N', 'Lon': '124.49W'},
#  '46053': {'Zone': 'east santa barbara', 'Lat': '34.24N', 'Lon': '119.84W'},
#  '46069': {'Zone': 'south santa rosa', 'Lat': '33.68N', 'Lon': '120.21W'},
#  '46071': {'Zone': 'western aleutians', 'Lat': '51.04N', 'Lon': '179.76E'},
#  '46072': {'Zone': 'central aleutians 230 nm sw dutch harbor',
#   'Lat': '51.65N',
#   'Lon': '172.15W'},
#  '46078': {'Zone': 'albatross bank', 'Lat': '55.56N', 'Lon': '152.60W'},
#  '46084': {'Zone': 'cape edgecumbe', 'Lat': '56.61N', 'Lon': '136.04W'},
#  '46086': {'Zone': 'san clemente basin', 'Lat': '32.50N', 'Lon': '118.05W'},
#  '46087': {'Zone': 'neah bay', 'Lat': '48.49N', 'Lon': '124.73W'},
#  '46088': {'Zone': 'new dungeness', 'Lat': '48.33N', 'Lon': '123.18W'},
#  '51000': {'Zone': 'northern hawaii one', 'Lat': '23.53N', 'Lon': '153.79W'},
#  '51001': {'Zone': 'northwestern hawaii one',
#   'Lat': '24.48N',
#   'Lon': '162.03W'},
#  '51002': {'Zone': 'southwest hawaii', 'Lat': '17.07N', 'Lon': '157.75W'},
#  'BURL1': {'Zone': 'southwest pass, la', 'Lat': '28.91N', 'Lon': '89.43W'},
#  'FFIA2': {'Zone': 'five fingers, ak', 'Lat': '57.27N', 'Lon': '133.63W'},
#  'LONF1': {'Zone': 'long key, fl', 'Lat': '24.84N', 'Lon': '80.86W'},
#  'MDRM1': {'Zone': 'mt. desert rock, me', 'Lat': '43.97N', 'Lon': '68.13W'},
#  'MRKA2': {'Zone': 'middle rock light, ak', 'Lat': '61.08N', 'Lon': '146.66W'},
#  'POTA2': {'Zone': 'potato point, ak', 'Lat': '61.06N', 'Lon': '146.70W'},
#  'SANF1': {'Zone': 'sand key, fl', 'Lat': '24.46N', 'Lon': '81.88W'},
#  'SBIO1': {'Zone': 'south bass island, oh', 'Lat': '41.63N', 'Lon': '82.84W'}}

# %%
id_problem = 46072
metadata = get_station_metadata(id_problem)  # Utilise buoy_id au lieu de station_id_from_df
    # Changer le nom de la variable retournée par parse_buoy_json
parsed_station_id, station_zone, lat_buoy, lon_buoy = parse_buoy_json(metadata)

print(f'{metadata}\n {lat_buoy}\n {lon_buoy}')
# Out:
# {'Watch circle radius': '3629 yards', 'Water depth': '3589 m', 'Sea temp depth': '2 m below water line', 'Barometer elevation': '2.4 m above mean sea level', 'Anemometer height': '3.8 m above site elevation', 'Air temp height': '3.4 m above site elevation', 'Site elevation': 'sea level', 'Location': '51.645 N 172.145 W (51°38\'42" N 172°8\'42" W)', 'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload', 'Name': 'Station 46072 (LLNR 27510) - CENTRAL ALEUTIANS 230 NM SW Dutch Harbor'}
#  51.65N
#  172.15W

# %%
# Convertir le dictionnaire en DataFrame, en utilisant 'buoy_id' comme index
df_buoy_datas = pd.DataFrame.from_dict(buoy_datas, orient='index')

# Réinitialiser l'index et renommer la colonne
df_buoy_datas = df_buoy_datas.reset_index(drop=False)
df_buoy_datas.rename(columns={"index": "Station ID"}, inplace=True)

table_name="buoy_datas"
# Charger les données dans la table
try:
    load_data_in_table(conn=conn, schema=schema, df=df_buoy_datas, table_name=table_name, key_column="Station ID")
    print(f"Données chargées avec succès dans la table {table_name}.")
except Exception as e:
    print(f"Erreur lors du chargement des données : {e}")

# Affichage du DataFrame
df_buoy_datas.head()
# Out:
# No new data to insert.
#
# No new data was inserted.
# Rows in table before insertion: 39
# Rows inserted: 0
# Rows in table after insertion: 39
#
# Données chargées avec succès dans la table buoy_datas.
#   Station ID          Zone     Lat     Lon
# 0      41008    grays reef  31.40N  80.87W
# 1      41044  ne st martin  21.58N  58.63W
# 2      42001      mid gulf  25.93N  89.66W
# 3      42002     west gulf  25.95N  93.78W
# 4      42012  orange beach  30.06N  87.55W

# %% [markdown]
# Map Visualization

# %%
list_coords=[]

for id in buoy_list:
    metadata = get_station_metadata(id)
    
    station_id, station_zone, lat_buoy, lon_buoy = parse_buoy_json(metadata)
    lat_buoy, lon_buoy = convert_coordinates(lat_buoy,lon_buoy)
    coords = [station_id, station_zone, lat_buoy, lon_buoy]
    list_coords.append(coords)

def barycentre(coords):
    x_coords = [item[2] for item in coords]
    y_coords = [item[3] for item in coords]

    x_barycentre = sum(x_coords) / len(coords)
    y_barycentre = sum(y_coords) / len(coords)

    return [x_barycentre, y_barycentre]

# Exemple d'utilisation
coords = [[1, 2], [3, 4], [5, 6], [7, 8]]
centre = barycentre(list_coords)
print(list_coords)
print("Coordonnées du barycentre :", centre)
# Out:
# [['41008', 'grays reef', 31.4, -80.87], ['41044', 'ne st martin', 21.58, -58.63], ['42001', 'mid gulf', 25.93, -89.66], ['42002', 'west gulf', 25.95, -93.78], ['42012', 'orange beach', 30.06, -87.55], ['42036', 'west tampa', 28.5, -84.5], ['42056', 'yucatan basin', 19.82, -84.98], ['42058', 'central caribbean', 14.51, -75.15], ['44020', 'nantucket sound', 41.5, -70.28], ['44025', 'long island', 40.26, -73.17], ['44027', 'jonesport, me', 44.28, -67.3], ['44065', 'new york harbor entrance', 40.37, -73.7], ['46001', 'western gulf of alaska', 56.3, -148.03], ['46006', 'southeast papa', 40.76, -137.38], ['46014', 'pt arena', 39.23, -123.98], ['46022', 'eel river', 40.72, -124.54], ['46025', 'santa monica basin', 33.76, -119.05], ['46027', 'st georges', 41.84, -124.38], ['46029', 'columbia river bar', 46.16, -124.49], ['46053', 'east santa barbara', 34.24, -119.84], ['46069', 'south santa rosa', 33.68, -120.21], ['46071', 'western aleutians', 51.04, 179.76], ['46072', 'central aleutians 230 nm sw dutch harbor', 51.65, -172.15], ['46078', 'albatross bank', 55.56, -152.6], ['46084', 'cape edgecumbe', 56.61, -136.04], ['46086', 'san clemente basin', 32.5, -118.05], ['46087', 'neah bay', 48.49, -124.73], ['46088', 'new dungeness', 48.33, -123.18], ['51000', 'northern hawaii one', 23.53, -153.79], ['51001', 'northwestern hawaii one', 24.48, -162.03], ['51002', 'southwest hawaii', 17.07, -157.75], ['BURL1', 'southwest pass, la', 28.91, -89.43], ['FFIA2', 'five fingers, ak', 57.27, -133.63], ['LONF1', 'long key, fl', 24.84, -80.86], ['MDRM1', 'mt. desert rock, me', 43.97, -68.13], ['MRKA2', 'middle rock light, ak', 61.08, -146.66], ['POTA2', 'potato point, ak', 61.06, -146.7], ['SANF1', 'sand key, fl', 24.46, -81.88], ['SBIO1', 'south bass island, oh', 41.63, -82.84]]
# Coordonnées du barycentre : [38.03410256410256, -103.38871794871794]

# %%
map = folium.Map(location=(centre[0],centre[1]), 
                 tiles="Esri.WorldImagery", 
                 zoom_start=2.5, attr="Données fournies par Esri")
for loc in list_coords:
    lat = loc[2]
    lon = loc[3]
    station_id = loc[0]
    station_zone = loc[1]
    folium.Marker(
    location=[lat, lon],
    popup=f"Station ID: {station_id}\n\nZone: {station_zone}\nLat: {lat}\n\nLon: {lon}",
    icon=folium.Icon(icon="cloud"),
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f05c568603b7bd316bca0d5786591284 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f05c568603b7bd316bca0d5786591284&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f05c568603b7bd316bca0d5786591284 = L.map(
#                 &quot;map_f05c568603b7bd316bca0d5786591284&quot;,
#                 {
#                     center: [38.03410256410256, -103.38871794871794],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c57f34783ae3df93de7a5048743c2109 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Donn\u00e9es fournies par Esri&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c57f34783ae3df93de7a5048743c2109.addTo(map_f05c568603b7bd316bca0d5786591284);
#
#
#             var marker_340f9a46a4a429a6342821b1e67e1c13 = L.marker(
#                 [31.4, -80.87],
#                 {
# }
#             ).addTo(map_f05c568603b7bd316bca0d5786591284);
#
#
#             var icon_838c1756e630b8dce52ee22c9d44462b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c032555101afa0fd06af987e47ed4041 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6ebec8b0fd50cde18018b94d2d8fd7a = $(`&lt;div id=&quot;html_b6ebec8b0fd50cde18018b94d2d8fd7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 41008  Zone: grays reef Lat: 31.4  Lon: -80.87&lt;/div&gt;`)[0];
#                 popup_c032555101afa0fd06af987e47ed4041.setContent(html_b6ebec8b0fd50cde18018b94d2d8fd7a);
#
#
#
#         marker_340f9a46a4a429a6342821b1e67e1c13.bindPopup(popup_c032555101afa0fd06af987e47ed4041)
#         ;
#
#
#
#
#                 marker_340f9a46a4a429a6342821b1e67e1c13.setIcon(icon_838c1756e630b8dce52ee22c9d44462b);
#
#
#             var marker_203a36a5b3847fc0ed252e2d21224a82 = L.marker(
#                 [21.58, -58.63],
#                 {
# }
#             ).addTo(map_f05c568603b7bd316bca0d5786591284);
#
#
#             var icon_4b23fa26a223d7fc98beac3bf49dac24 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_33e7b490e227543b38d81bda1d50308a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_989a419325cfae4355ec6febd1b0704d = $(`&lt;div id=&quot;html_989a419325cfae4355ec6febd1b0704d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 41044  Zone: ne st martin Lat: 21.58  Lon: -58.63&lt;/div&gt;`)[0];
#                 popup_33e7b490e227543b38d81bda1d50308a.setContent(html_989a419325cfae4355ec6febd1b0704d);
#
#
#
#         marker_203a36a5b3847fc0ed252e2d21224a82.bindPopup(popup_33e7b490e227543b38d81bda1d50308a)
#         ;
#
#
#
#
#                 marker_203a36a5b3847fc0ed252e2d21224a82.setIcon(icon_4b23fa26a223d7fc98beac3bf49dac24);
#
#
#             var marker_dbd8efd00e1ad1756d7f3d5deeb31da9 = L.marker(
#                 [25.93, -89.66],
#                 {
# }
#             ).addTo(map_f05c568603b7bd316bca0d5786591284);
#
#
#             var icon_44cd717c80e9f8b453ce9fe84e0412f7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3e150c137c7f09de86d75ec0fd9c57d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_645b9c944c1fae45cbebd464ebb9f361 = $(`&lt;div id=&quot;html_645b9c944c1fae45cbebd464ebb9f361&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station ID: 42001  Zone: mid gulf Lat: 25.93  Lon: -89.66&lt;/div&gt;`)[0];
#                 popup_3e150c137c7f09de86d75ec0fd9c57d5.setContent(html_645b9c944c1fae45cbebd464ebb9f361);
#
#
#
#         marker_dbd8efd00e1ad1756d7f3d5deeb31da9.bindPopup(popup_3e150c137c7f09de86d75ec0fd9c57d5)
#         ;
#
#
#
#
#                 marker_dbd8efd00e1ad1756d7f3d5deeb31da9.setIcon(icon_44cd717c80e9f8b453ce9fe84e0412f7);
#
#
#             var marker_e023755fc562dcdd583ea841bd6bbc9c = L.marker(
#                 [25.95, -93.78],
#                 {
# }
#             ).addTo(map_f05c568603b7bd316bca0d5786591284);

# %% [markdown]
# Columns Check Tests

# %%
choice = random.choice(buoy_list)
choice
# Out:
# '42012'

# %%
df_marine_test = NDBC.realtime_observations(choice)
print(f'{df_marine_test.shape[0]} rows \n\n{df_marine_test.isna().sum()}')
df_marine_test.head(1)
# Out:
# 6498 rows
#
# wind_direction              120
# wind_speed                    3
# wind_gust                     3
# wave_height                6268
# dominant_wave_period       6359
# average_wave_period        6268
# dominant_wave_direction    6272
# pressure                      0
# air_temperature              15
# water_temperature           183
# dewpoint                     15
# visibility                 6498
# 3hr_pressure_tendency      5416
# water_level_above_mean     6498
# time                          0
# dtype: int64
#    wind_direction  wind_speed  wind_gust  wave_height  dominant_wave_period  \
# 0            50.0         2.0        3.0          NaN                   NaN
#
#    average_wave_period  dominant_wave_direction  pressure  air_temperature  \
# 0                  NaN                      NaN    1021.3             17.8
#
#    water_temperature  dewpoint  visibility  3hr_pressure_tendency  \
# 0               19.6      15.3         NaN                    NaN
#
#    water_level_above_mean                      time
# 0                     NaN 2025-03-25 16:10:00+00:00

# %% [markdown]
# Check test API Open-Meteo

# %%
df_meteo_test = meteo_api_request(coordinates=[12, 23])
print(f'{df_meteo_test.shape[0]} rows \n{df_meteo_test.isna().sum()}')
df_meteo_test.head(1)
# Out:
# 2376 rows
# date                        0
# temperature_2m             42
# relative_humidity_2m       42
# dew_point_2m               42
# precipitation              42
# rain                       42
# showers                    42
# pressure_msl               42
# surface_pressure           42
# cloud_cover                42
# cloud_cover_low            42
# cloud_cover_mid            42
# cloud_cover_high           42
# visibility                 42
# wind_speed_10m             42
# soil_temperature_0cm      298
# soil_moisture_0_to_1cm    298
# is_day                      0
# dtype: int64
#                        date  temperature_2m  relative_humidity_2m  \
# 0 2024-12-23 00:00:00+00:00             NaN                   NaN
#
#    dew_point_2m  precipitation  rain  showers  pressure_msl  surface_pressure  \
# 0           NaN            NaN   NaN      NaN           NaN               NaN
#
#    cloud_cover  cloud_cover_low  cloud_cover_mid  cloud_cover_high  \
# 0          NaN              NaN              NaN               NaN
#
#    visibility  wind_speed_10m  soil_temperature_0cm  soil_moisture_0_to_1cm  \
# 0         NaN             NaN                   NaN                     NaN
#
#    is_day
# 0     0.0

# %%
metadata_extracted = get_station_metadata(choice)
metadata_extracted
# Out:
# {'Watch circle radius': '74 yards',
#  'Water depth': '23.5 m',
#  'Sea temp depth': '2 m below water line',
#  'Barometer elevation': '2.4 m above mean sea level',
#  'Anemometer height': '3.8 m above site elevation',
#  'Air temp height': '3.4 m above site elevation',
#  'Site elevation': 'sea level',
#  'Location': '30.060 N 87.548 W (30°3\'36" N 87°32\'54" W)',
#  'Statation Type': 'Owned and maintained by National Data Buoy Center, 3-meter discus buoy, SCOOP payload',
#  'Name': 'Station 42012 (LLNR 138) - ORANGE BEACH - 44 NM SE of Mobile, AL'}

# %%
station_id, station_zone, lat_buoy, lon_buoy = parse_buoy_json(metadata_extracted)
print(f'{station_name}\n{station_id}\n{station_zone}\n{lat_buoy}\n{lon_buoy}\n')
# Out:
# West Point, Wa
# 42012
# orange beach
# 30.06N
# 87.55W

# %% [markdown]
# Big API Call Loop

# %%
# Définir le dossier où sauvegarder les fichiers
marine_output_dir = r"marine_tables"
meteo_output_dir = r"meteo_tables"
# S'assurer que le dossier existe (le créer s'il n'existe pas)
os.makedirs(marine_output_dir, exist_ok=True)
os.makedirs(meteo_output_dir, exist_ok=True)

dict_df = {}
count = 1
total = len(buoy_datas)

for buoy_id in buoy_datas:  # Boucle sur les bouées dans le dictionnaire
    dict_df[buoy_id] = {}

    # Récupérer les métadonnées de la bouée
    metadata_extracted = get_station_metadata(buoy_id)
    
    station_id, station_zone, lat_buoy, lon_buoy = parse_buoy_json(metadata_extracted)
    
    buoy_datas[buoy_id]["Station Name"] = station_name
    buoy_datas[buoy_id]["Station ID"] = station_id
    buoy_datas[buoy_id]["Zone"] = station_zone
    buoy_datas[buoy_id]["Lat"] = lat
    buoy_datas[buoy_id]["Lon"] = lon

    Bronze_Marine_Table_Name = f"station_{station_id}_marine_{station_zone}"
    Bronze_Marine_Table_Name = Bronze_Marine_Table_Name.replace('.', '_').replace('-', '_')

    Bronze_Meteo_Table_Name = f"station_{station_id}_meteo_{station_zone}"
    Bronze_Meteo_Table_Name = Bronze_Meteo_Table_Name.replace('.', '_').replace('-', '_')

    # Construire le chemin complet du fichier
    marine_csv_path = os.path.join(marine_output_dir, Bronze_Marine_Table_Name + ".csv")
    meteo_csv_path = os.path.join(meteo_output_dir, Bronze_Meteo_Table_Name + ".csv")

    duo = [Bronze_Marine_Table_Name, Bronze_Meteo_Table_Name]

    print(f"\n{'='*50}\nIteration: {count}/{total} | Bouée ID: {buoy_id}")
    print(f"{'='*50}")
    
    # NOAA API CALL (avec timeout)
    try:
        df_marine = NDBC.realtime_observations(buoy_id)  # Timeout après 30 secondes
        if df_marine is None or df_marine.empty:
            print(f"⚠️ Marine Data is empty for buoy {buoy_id}")
        else:
            df_marine["Station ID"] = buoy_id
            buoy_datas[buoy_id]["Marine Dataframe"] = df_marine
            print(f"🌊 Marine Data Successfully collected for buoy {buoy_id}")
            dict_df[buoy_id]["Marine DataFrame"] = df_marine
            df_marine.to_csv(marine_csv_path , mode='w', index=True, index_label="time")
            load_data_in_table(conn, schema, table_name=Bronze_Marine_Table_Name, df=df_marine, key_column="time")

    except Exception as e:
        print(f"❌ Failed to collect Marine Data for buoy {buoy_id}: \n{e}\n")
        
    # Open-Meteo API Call (avec timeout)
    try:
        df_meteo = meteo_api_request(coordinates=[lat, lon])  # Timeout après 30 secondes
        if df_meteo is None or df_meteo.empty:
            print(f"⚠️ Meteo Data is empty for buoy {buoy_id}")
        else:
            buoy_datas[buoy_id]["Meteo DataFrame"] = df_meteo
            print(f"🌦️ Meteo Data Successfully collected for buoy {buoy_id}")
            dict_df[buoy_id]["Meteo DataFrame"] = df_meteo
            df_meteo.to_csv(meteo_csv_path , mode='w', index=True, index_label="date")
            load_data_in_table(conn, schema, table_name=Bronze_Meteo_Table_Name, df=df_meteo, key_column="date")

    except Exception as e:
        print(f"⚠️ Bouée {buoy_id} : Erreur à l'insertion des données:\n{e}\n")

    count += 1

# Final summary
print('\n' + '='*50)
list_tables_info(conn=conn, schema=schema)
print('\n' + '='*50)

text = "Processus Bronze Du Projet Oceanography ML terminé !"
show_popup(text=text)
# Out:
# ==================================================
# Iteration: 1/39 | Bouée ID: 41008
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 41008
# New data inserted successfully!
# Rows in table before insertion: 6544
# Rows inserted: 429
# Rows in table after insertion: 6973
#
# 🌦️ Meteo Data Successfully collected for buoy 41008
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 2/39 | Bouée ID: 41044
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 41044
# New data inserted successfully!
# Rows in table before insertion: 6512
# Rows inserted: 427
# Rows in table after insertion: 6939
#
# 🌦️ Meteo Data Successfully collected for buoy 41044
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 3/39 | Bouée ID: 42001
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 42001
# New data inserted successfully!
# Rows in table before insertion: 1365
# Rows inserted: 429
# Rows in table after insertion: 1794
#
# 🌦️ Meteo Data Successfully collected for buoy 42001
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 4/39 | Bouée ID: 42002
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 42002
# New data inserted successfully!
# Rows in table before insertion: 1517
# Rows inserted: 430
# Rows in table after insertion: 1947
#
# 🌦️ Meteo Data Successfully collected for buoy 42002
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 5/39 | Bouée ID: 42012
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 42012
# New data inserted successfully!
# Rows in table before insertion: 6503
# Rows inserted: 425
# Rows in table after insertion: 6928
#
# 🌦️ Meteo Data Successfully collected for buoy 42012
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 6/39 | Bouée ID: 42036
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 42036
# New data inserted successfully!
# Rows in table before insertion: 6485
# Rows inserted: 429
# Rows in table after insertion: 6914
#
# 🌦️ Meteo Data Successfully collected for buoy 42036
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 7/39 | Bouée ID: 42056
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 42056
# New data inserted successfully!
# Rows in table before insertion: 6515
# Rows inserted: 428
# Rows in table after insertion: 6943
#
# 🌦️ Meteo Data Successfully collected for buoy 42056
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 8/39 | Bouée ID: 42058
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 42058
# New data inserted successfully!
# Rows in table before insertion: 6515
# Rows inserted: 427
# Rows in table after insertion: 6942
#
# 🌦️ Meteo Data Successfully collected for buoy 42058
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 9/39 | Bouée ID: 44020
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 44020
# New data inserted successfully!
# Rows in table before insertion: 6519
# Rows inserted: 428
# Rows in table after insertion: 6947
#
# 🌦️ Meteo Data Successfully collected for buoy 44020
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 10/39 | Bouée ID: 44025
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 44025
# New data inserted successfully!
# Rows in table before insertion: 6533
# Rows inserted: 428
# Rows in table after insertion: 6961
#
# 🌦️ Meteo Data Successfully collected for buoy 44025
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 11/39 | Bouée ID: 44027
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 44027
# New data inserted successfully!
# Rows in table before insertion: 6514
# Rows inserted: 427
# Rows in table after insertion: 6941
#
# 🌦️ Meteo Data Successfully collected for buoy 44027
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 12/39 | Bouée ID: 44065
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 44065
# New data inserted successfully!
# Rows in table before insertion: 6505
# Rows inserted: 426
# Rows in table after insertion: 6931
#
# 🌦️ Meteo Data Successfully collected for buoy 44065
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 13/39 | Bouée ID: 46001
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46001
# New data inserted successfully!
# Rows in table before insertion: 6509
# Rows inserted: 428
# Rows in table after insertion: 6937
#
# 🌦️ Meteo Data Successfully collected for buoy 46001
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 14/39 | Bouée ID: 46006
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46006
# New data inserted successfully!
# Rows in table before insertion: 6517
# Rows inserted: 428
# Rows in table after insertion: 6945
#
# 🌦️ Meteo Data Successfully collected for buoy 46006
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 15/39 | Bouée ID: 46014
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46014
# New data inserted successfully!
# Rows in table before insertion: 6558
# Rows inserted: 432
# Rows in table after insertion: 6990
#
# 🌦️ Meteo Data Successfully collected for buoy 46014
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 16/39 | Bouée ID: 46022
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46022
# New data inserted successfully!
# Rows in table before insertion: 6552
# Rows inserted: 451
# Rows in table after insertion: 7003
#
# 🌦️ Meteo Data Successfully collected for buoy 46022
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 17/39 | Bouée ID: 46025
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46025
# New data inserted successfully!
# Rows in table before insertion: 6554
# Rows inserted: 428
# Rows in table after insertion: 6982
#
# 🌦️ Meteo Data Successfully collected for buoy 46025
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 18/39 | Bouée ID: 46027
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46027
# New data inserted successfully!
# Rows in table before insertion: 6558
# Rows inserted: 431
# Rows in table after insertion: 6989
#
# 🌦️ Meteo Data Successfully collected for buoy 46027
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 19/39 | Bouée ID: 46029
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46029
# New data inserted successfully!
# Rows in table before insertion: 6556
# Rows inserted: 430
# Rows in table after insertion: 6986
#
# 🌦️ Meteo Data Successfully collected for buoy 46029
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 20/39 | Bouée ID: 46053
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46053
# New data inserted successfully!
# Rows in table before insertion: 6554
# Rows inserted: 431
# Rows in table after insertion: 6985
#
# 🌦️ Meteo Data Successfully collected for buoy 46053
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 21/39 | Bouée ID: 46069
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46069
# New data inserted successfully!
# Rows in table before insertion: 6533
# Rows inserted: 428
# Rows in table after insertion: 6961
#
# 🌦️ Meteo Data Successfully collected for buoy 46069
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 22/39 | Bouée ID: 46071
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46071
# New data inserted successfully!
# Rows in table before insertion: 6516
# Rows inserted: 426
# Rows in table after insertion: 6942
#
# 🌦️ Meteo Data Successfully collected for buoy 46071
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 23/39 | Bouée ID: 46072
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46072
# New data inserted successfully!
# Rows in table before insertion: 6518
# Rows inserted: 427
# Rows in table after insertion: 6945
#
# 🌦️ Meteo Data Successfully collected for buoy 46072
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 24/39 | Bouée ID: 46078
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46078
# New data inserted successfully!
# Rows in table before insertion: 6512
# Rows inserted: 426
# Rows in table after insertion: 6938
#
# 🌦️ Meteo Data Successfully collected for buoy 46078
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 25/39 | Bouée ID: 46084
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46084
# New data inserted successfully!
# Rows in table before insertion: 6518
# Rows inserted: 426
# Rows in table after insertion: 6944
#
# 🌦️ Meteo Data Successfully collected for buoy 46084
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 26/39 | Bouée ID: 46086
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46086
# New data inserted successfully!
# Rows in table before insertion: 6556
# Rows inserted: 430
# Rows in table after insertion: 6986
#
# 🌦️ Meteo Data Successfully collected for buoy 46086
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 27/39 | Bouée ID: 46087
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46087
# New data inserted successfully!
# Rows in table before insertion: 6564
# Rows inserted: 429
# Rows in table after insertion: 6993
#
# 🌦️ Meteo Data Successfully collected for buoy 46087
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 28/39 | Bouée ID: 46088
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 46088
# New data inserted successfully!
# Rows in table before insertion: 6555
# Rows inserted: 431
# Rows in table after insertion: 6986
#
# 🌦️ Meteo Data Successfully collected for buoy 46088
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 29/39 | Bouée ID: 51000
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 51000
# New data inserted successfully!
# Rows in table before insertion: 6518
# Rows inserted: 427
# Rows in table after insertion: 6945
#
# 🌦️ Meteo Data Successfully collected for buoy 51000
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 30/39 | Bouée ID: 51001
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 51001
# New data inserted successfully!
# Rows in table before insertion: 6513
# Rows inserted: 425
# Rows in table after insertion: 6938
#
# 🌦️ Meteo Data Successfully collected for buoy 51001
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 31/39 | Bouée ID: 51002
# ==================================================
# 🌊 Marine Data Successfully collected for buoy 51002
# New data inserted successfully!
# Rows in table before insertion: 6510
# Rows inserted: 425
# Rows in table after insertion: 6935
#
# 🌦️ Meteo Data Successfully collected for buoy 51002
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 32/39 | Bouée ID: BURL1
# ==================================================
# 🌊 Marine Data Successfully collected for buoy BURL1
# New data inserted successfully!
# Rows in table before insertion: 1094
# Rows inserted: 72
# Rows in table after insertion: 1166
#
# 🌦️ Meteo Data Successfully collected for buoy BURL1
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 33/39 | Bouée ID: FFIA2
# ==================================================
# 🌊 Marine Data Successfully collected for buoy FFIA2
# New data inserted successfully!
# Rows in table before insertion: 1097
# Rows inserted: 72
# Rows in table after insertion: 1169
#
# 🌦️ Meteo Data Successfully collected for buoy FFIA2
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 34/39 | Bouée ID: LONF1
# ==================================================
# 🌊 Marine Data Successfully collected for buoy LONF1
# New data inserted successfully!
# Rows in table before insertion: 6435
# Rows inserted: 427
# Rows in table after insertion: 6862
#
# 🌦️ Meteo Data Successfully collected for buoy LONF1
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 35/39 | Bouée ID: MDRM1
# ==================================================
# 🌊 Marine Data Successfully collected for buoy MDRM1
# New data inserted successfully!
# Rows in table before insertion: 1096
# Rows inserted: 72
# Rows in table after insertion: 1168
#
# 🌦️ Meteo Data Successfully collected for buoy MDRM1
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 36/39 | Bouée ID: MRKA2
# ==================================================
# 🌊 Marine Data Successfully collected for buoy MRKA2
# New data inserted successfully!
# Rows in table before insertion: 2190
# Rows inserted: 144
# Rows in table after insertion: 2334
#
# 🌦️ Meteo Data Successfully collected for buoy MRKA2
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 37/39 | Bouée ID: POTA2
# ==================================================
# 🌊 Marine Data Successfully collected for buoy POTA2
# New data inserted successfully!
# Rows in table before insertion: 2190
# Rows inserted: 144
# Rows in table after insertion: 2334
#
# 🌦️ Meteo Data Successfully collected for buoy POTA2
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 38/39 | Bouée ID: SANF1
# ==================================================
# 🌊 Marine Data Successfully collected for buoy SANF1
# New data inserted successfully!
# Rows in table before insertion: 6474
# Rows inserted: 428
# Rows in table after insertion: 6902
#
# 🌦️ Meteo Data Successfully collected for buoy SANF1
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Iteration: 39/39 | Bouée ID: SBIO1
# ==================================================
# 🌊 Marine Data Successfully collected for buoy SBIO1
# New data inserted successfully!
# Rows in table before insertion: 1095
# Rows inserted: 72
# Rows in table after insertion: 1167
#
# 🌦️ Meteo Data Successfully collected for buoy SBIO1
# New data inserted successfully!
# Rows in table before insertion: 2376
# Rows inserted: 72
# Rows in table after insertion: 2448
#
#
# ==================================================
# Tables dans le schéma 'Bronze':
#
# Table: buoy_datas
# Nombre de lignes: 39
# Table: station_41008_marine_grays reef
# Nombre de lignes: 6973
# Table: station_41008_meteo_grays reef
# Nombre de lignes: 2448
# Table: station_41044_marine_ne st martin
# Nombre de lignes: 6939
# Table: station_41044_meteo_ne st martin
# Nombre de lignes: 2448
# Table: station_42001_marine_mid gulf
# Nombre de lignes: 1794
# Table: station_42001_meteo_mid gulf
# Nombre de lignes: 2448
# Table: station_42002_marine_west gulf
# Nombre de lignes: 1947
# Table: station_42002_meteo_west gulf
# Nombre de lignes: 2448
# Table: station_42012_marine_orange beach
# Nombre de lignes: 6928
# Table: station_42012_meteo_orange beach
# Nombre de lignes: 2448
# Table: station_42036_marine_west tampa
# Nombre de lignes: 6914
# Table: station_42036_meteo_west tampa
# Nombre de lignes: 2448
# Table: station_42056_marine_yucatan basin
# Nombre de lignes: 6943
# Table: station_42056_meteo_yucatan basin
# Nombre de lignes: 2448
# Table: station_42058_marine_central caribbean
# Nombre de lignes: 6942
# Table: station_42058_meteo_central caribbean
# Nombre de lignes: 2448
# Table: station_44020_marine_nantucket sound
# Nombre de lignes: 6947
# Table: station_44020_meteo_nantucket sound
# Nombre de lignes: 2448
# Table: station_44025_marine_long island
# Nombre de lignes: 6961
# Table: station_44025_meteo_long island
# Nombre de lignes: 2448
# Table: station_44027_marine_jonesport, me
# Nombre de lignes: 6941
# Table: station_44027_meteo_jonesport, me
# Nombre de lignes: 2448
# Table: station_44065_marine_new york harbor entrance
# Nombre de lignes: 6931
# Table: station_44065_meteo_new york harbor entrance
# Nombre de lignes: 2448
# Table: station_46001_marine_western gulf of alaska
# Nombre de lignes: 6937
# Table: station_46001_meteo_western gulf of alaska
# Nombre de lignes: 2448
# Table: station_46006_marine_southeast papa
# Nombre de lignes: 6945
# Table: station_46006_meteo_southeast papa
# Nombre de lignes: 2448
# Table: station_46014_marine_pt arena
# Nombre de lignes: 6990
# Table: station_46014_meteo_pt arena
# Nombre de lignes: 2448
# Table: station_46022_marine_eel river
# Nombre de lignes: 7003
# Table: station_46022_meteo_eel river
# Nombre de lignes: 2448
# Table: station_46025_marine_santa monica basin
# Nombre de lignes: 6982
# Table: station_46025_meteo_santa monica basin
# Nombre de lignes: 2448
# Table: station_46027_marine_st georges
# Nombre de lignes: 6989
# Table: station_46027_meteo_st georges
# Nombre de lignes: 2448
# Table: station_46029_marine_columbia river bar
# Nombre de lignes: 6986
# Table: station_46029_meteo_columbia river bar
# Nombre de lignes: 2448
# Table: station_46053_marine_east santa barbara
# Nombre de lignes: 6985
# Table: station_46053_meteo_east santa barbara
# Nombre de lignes: 2448
# Table: station_46069_marine_south santa rosa
# Nombre de lignes: 6961
# Table: station_46069_meteo_south santa rosa
# Nombre de lignes: 2448
# Table: station_46071_marine_western aleutians
# Nombre de lignes: 6942
# Table: station_46071_meteo_western aleutians
# Nombre de lignes: 2448
# Table: station_46072_marine_central aleutians 230 nm sw dutch harbor
# Nombre de lignes: 6945
# Table: station_46072_meteo_central aleutians 230 nm sw dutch harbor
# Nombre de lignes: 2448
# Table: station_46078_marine_albatross bank
# Nombre de lignes: 6938
# Table: station_46078_meteo_albatross bank
# Nombre de lignes: 2448
# Table: station_46084_marine_cape edgecumbe
# Nombre de lignes: 6944
# Table: station_46084_meteo_cape edgecumbe
# Nombre de lignes: 2448
# Table: station_46086_marine_san clemente basin
# Nombre de lignes: 6986
# Table: station_46086_meteo_san clemente basin
# Nombre de lignes: 2448
# Table: station_46087_marine_neah bay
# Nombre de lignes: 6993
# Table: station_46087_meteo_neah bay
# Nombre de lignes: 2448
# Table: station_46088_marine_new dungeness
# Nombre de lignes: 6986
# Table: station_46088_meteo_new dungeness
# Nombre de lignes: 2448
# Table: station_51000_marine_northern hawaii one
# Nombre de lignes: 6945
# Table: station_51000_meteo_northern hawaii one
# Nombre de lignes: 2448
# Table: station_51001_marine_northwestern hawaii one
# Nombre de lignes: 6938
# Table: station_51001_meteo_northwestern hawaii one
# Nombre de lignes: 2448
# Table: station_51002_marine_southwest hawaii
# Nombre de lignes: 6935
# Table: station_51002_meteo_southwest hawaii
# Nombre de lignes: 2448
# Table: station_BURL1_marine_southwest pass, la
# Nombre de lignes: 1166
# Table: station_BURL1_meteo_southwest pass, la
# Nombre de lignes: 2448
# Table: station_FFIA2_marine_five fingers, ak
# Nombre de lignes: 1169
# Table: station_FFIA2_meteo_five fingers, ak
# Nombre de lignes: 2448
# Table: station_LONF1_marine_long key, fl
# Nombre de lignes: 6862
# Table: station_LONF1_meteo_long key, fl
# Nombre de lignes: 2448
# Table: station_MDRM1_marine_mt_ desert rock, me
# Nombre de lignes: 1168
# Table: station_MDRM1_meteo_mt_ desert rock, me
# Nombre de lignes: 2448
# Table: station_MRKA2_marine_middle rock light, ak
# Nombre de lignes: 2334
# Table: station_MRKA2_meteo_middle rock light, ak
# Nombre de lignes: 2448
# Table: station_POTA2_marine_potato point, ak
# Nombre de lignes: 2334
# Table: station_POTA2_meteo_potato point, ak
# Nombre de lignes: 2448
# Table: station_SANF1_marine_sand key, fl
# Nombre de lignes: 6902
# Table: station_SANF1_meteo_sand key, fl
# Nombre de lignes: 2448
# Table: station_SBIO1_marine_south bass island, oh
# Nombre de lignes: 1167
# Table: station_SBIO1_meteo_south bass island, oh
# Nombre de lignes: 2448
#
# ==================================================

# %%
df_marine.columns
# Out:
# Index(['wind_direction', 'wind_speed', 'wind_gust', 'wave_height',
#        'dominant_wave_period', 'average_wave_period',
#        'dominant_wave_direction', 'pressure', 'air_temperature',
#        'water_temperature', 'dewpoint', 'visibility', '3hr_pressure_tendency',
#        'water_level_above_mean', 'time', 'Station ID'],
#       dtype='object')

# %%
df_meteo.columns
# Out:
# Index(['date', 'temperature_2m', 'relative_humidity_2m', 'dew_point_2m',
#        'precipitation', 'rain', 'showers', 'pressure_msl', 'surface_pressure',
#        'cloud_cover', 'cloud_cover_low', 'cloud_cover_mid', 'cloud_cover_high',
#        'visibility', 'wind_speed_10m', 'soil_temperature_0cm',
#        'soil_moisture_0_to_1cm', 'is_day'],
#       dtype='object')

# %%
# def drop_schema_or_tables(conn, schema_name, drop_schema=False):
#     try:
#         if drop_schema:
#             # Supprimer le schéma si drop_schema est True
#             print(f"Dropping schema {schema_name}...")
#             conn.execute(text(f"DROP SCHEMA IF EXISTS \"{schema_name}\" CASCADE;"))
#             conn.commit()
#             print(f"Schema {schema_name} dropped successfully.")
#         else:
#             # Supprimer toutes les tables dans le schéma
#             print(f"Dropping all tables in schema {schema_name}...")
#             conn.execute(text(f"""
#                 DO $$ 
#                 DECLARE
#                     r RECORD;
#                 BEGIN
#                     FOR r IN 
#                         SELECT table_name 
#                         FROM information_schema.tables 
#                         WHERE table_schema = :schema_name
#                     LOOP
#                         EXECUTE 'DROP TABLE IF EXISTS "' || :schema_name || '".' || quote_ident(r.table_name) || ' CASCADE';
#                     END LOOP;
#                 END $$;
#             """), {'schema_name': schema_name})
#             conn.commit()
#             print(f"All tables in schema {schema_name} dropped successfully.")
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         conn.rollback()
#         print("Transaction rolled back.")

# drop_schema_or_tables(conn=conn, schema_name=schema, drop_schema=False)

# %%
# def explore_dict(d, indent=0):
#     """ Fonction récursive pour afficher toute la structure du dictionnaire """
#     for key, value in d.items():
#         print(" " * indent + f"- {key}: {type(value)}")
#         if isinstance(value, dict):
#             explore_dict(value, indent + 4)  # Explorer récursivement avec une indentation
#         elif isinstance(value, list):
#             if len(value) > 0:
#                 print(" " * (indent + 4) + f"Liste ({len(value)} éléments), type du premier élément: {type(value[0])}")
#                 if isinstance(value[0], dict):
#                     explore_dict(value[0], indent + 8)  # Explorer si c'est une liste de dicts
#         else:
#             print(" " * (indent + 4) + f"Valeur: {value}")

# # Récupérer la première clé du dictionnaire
# first_key = next(iter(buoy_datas))
# print(f"Exploration de la première clé: {first_key}\n")

# # Exécuter la fonction sur le premier élément uniquement
# explore_dict({first_key: buoy_datas[first_key]})

# %%
# openmongo_creds = r'C:\Users\f.gionnane\Documents\Data Engineering\Credentials\mongo_creds.json'

# with open(openmongo_creds, 'r') as file:
#     content = json.load(file)
#     mongo_user = content["user"]
#     mongo_password = content["password"]
#     mongo_string = content["connection_string"]

# uri = mongo_string
# # Create a new client and connect to the server
# client = MongoClient(uri, server_api=ServerApi('1'))

# # Send a ping to confirm a successful connection
# try:
#     client.admin.command('ping')
#     print("Pinged your deployment. You successfully connected to MongoDB!")
# except Exception as e:
#     print(e)
#     print(f'{mongo_user}\n{mongo_password}\n{mongo_string}')

# %%
# Charger le fichier GeoJSON depuis l'URL
url = "https://gist.githubusercontent.com/jrrickard/8755532505a40f3b8317/raw/ecd98849d3a5f4502b773b986254f19af3b8d8fb/oceans.json"
geojson_data = requests.get(url).json()

# Créer une carte avec un fond satellite ESRI
m = folium.Map(location=[0, 0], zoom_start=3, tiles="Esri.WorldImagery")

# Ajouter le GeoJSON (les océans) à la carte
folium.GeoJson(geojson_data, name="Oceans").add_to(m)

# Fonction pour générer des coordonnées aléatoires dans l'océan
def random_ocean_coords():
    lat = random.uniform(-60, 60)  # Latitude dans les eaux de l'océan
    lon = random.uniform(-180, 180)  # Longitude dans les eaux de l'océan
    return lat, lon

# Générer un DataFrame avec des coordonnées, températures, hauteur des vagues, vitesse du vent, etc.
data = {
    "Coordinates": [],
    "Temperature (°C)": [],
    "Wave Height (m)": [],
    "Wind Speed (km/h)": []
}

# Générer 10 marqueurs avec des valeurs aléatoires
for _ in range(10):
    lat, lon = random_ocean_coords()
    
    # Générer des valeurs aléatoires pour la température, la hauteur des vagues et la vitesse du vent
    temperature = random.uniform(15, 30)  # Température entre 15 et 30°C
    wave_height = random.uniform(0.5, 5)  # Hauteur des vagues entre 0.5m et 5m
    wind_speed = random.uniform(10, 50)  # Vitesse du vent entre 10 km/h et 50 km/h
    
    # Ajouter ces valeurs dans le DataFrame
    data["Coordinates"].append((lat, lon))
    data["Temperature (°C)"].append(temperature)
    data["Wave Height (m)"].append(wave_height)
    data["Wind Speed (km/h)"].append(wind_speed)

# Créer un DataFrame pandas avec ces données
df = pd.DataFrame(data)

# Ajouter les marqueurs et cercles à la carte avec des couleurs dépendant de la température
for index, row in df.iterrows():
    lat, lon = row["Coordinates"]
    temperature = row["Temperature (°C)"]
    
    # Déterminer la couleur du cercle en fonction de la température
    if temperature < 20:
        fill_color = "blue"
    elif temperature < 25:
        fill_color = "green"
    else:
        fill_color = "red"
    
    # Ajouter un marqueur
    folium.Marker(
        location=[lat, lon],
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(m)
    
    # Ajouter un cercle autour du marqueur
    folium.CircleMarker(
        location=[lat, lon],
        radius=15,  # Rayon du cercle
        color="black",
        fill=True,
        fill_color=fill_color,
        fill_opacity=0.5
    ).add_to(m)

# Ajouter une couche de contrôle pour la carte
folium.LayerControl().add_to(m)

# Sauvegarder la carte dans un fichier HTML
m.save("ocean_markers_map.html")

# Affichage de la carte dans l'environnement interactif (si vous êtes dans un environnement Jupyter)
