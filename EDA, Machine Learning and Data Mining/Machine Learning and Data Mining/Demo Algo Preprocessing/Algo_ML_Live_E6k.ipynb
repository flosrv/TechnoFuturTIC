# %%
from Prepro_Live import MinMaxScalerHM
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
from DataGenerator import Generate_Data

import pandas as pd
import numpy as np 

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = Generate_Data()
df = df.get_data(size=20)
df
# Out:
#      Age  Salaire  Heures_travail      Ville   Education
# 0   44.0  25448.0            58.0       Lyon      Master
# 1   47.0  41983.0            20.0   Bordeaux     Licence
# 2   31.0  30817.0            45.0   Bordeaux     Licence
# 3   43.0  60447.0            27.0      Paris     Licence
# 4   58.0  42914.0            53.0      Paris      Master
# 5   34.0  57275.0            48.0       Lyon      Master
# 6   56.0  60651.0            37.0       Lyon  Secondaire
# 7   44.0  65224.0            31.0   Bordeaux     Licence
# 8   27.0  26085.0            21.0      Paris  Secondaire
# 9   58.0  68173.0            45.0     Nantes     Licence
# 10  27.0  74690.0            43.0     Nantes     Licence
# 11  26.0  59432.0            28.0  Marseille  Secondaire
# 12  53.0  26327.0            57.0       Lyon    Primaire
# 13  20.0  67148.0            38.0      Paris      Master
# 14  55.0  26815.0            31.0     Nantes      Master
# ...

# %%
scaler2 = MinMaxScalerHM()
scaler2.fit(df)
scaler2.transform(df)
# Out:
#          Age   Salaire  Heures_travail      Ville   Education
# 0   0.631579  0.000000        1.000000       Lyon      Master
# 1   0.710526  0.334304        0.000000   Bordeaux     Licence
# 2   0.289474  0.108550        0.657895   Bordeaux     Licence
# 3   0.605263  0.707608        0.184211      Paris     Licence
# 4   1.000000  0.353127        0.868421      Paris      Master
# 5   0.368421  0.643477        0.736842       Lyon      Master
# 6   0.947368  0.711732        0.447368       Lyon  Secondaire
# 7   0.631579  0.804189        0.289474   Bordeaux     Licence
# 8   0.184211  0.012879        0.026316      Paris  Secondaire
# 9   1.000000  0.863812        0.657895     Nantes     Licence
# 10  0.184211  0.995572        0.605263     Nantes     Licence
# 11  0.157895  0.687087        0.210526  Marseille  Secondaire
# 12  0.868421  0.017772        0.973684       Lyon    Primaire
# 13  0.000000  0.843088        0.473684      Paris      Master
# ...

# %%
sk_scaler = MinMaxScaler()
sk_scaler.fit_transform(df[['Age','Salaire','Heures_travail']])
# Out:
# array([[0.63157895, 0.        , 1.        ],
#        [0.71052632, 0.33430379, 0.        ],
#        [0.28947368, 0.10855017, 0.65789474],
#        [0.60526316, 0.70760801, 0.18421053],
#        [1.        , 0.35312671, 0.86842105],
#        [0.36842105, 0.64347668, 0.73684211],
#        [0.94736842, 0.71173248, 0.44736842],
#        [0.63157895, 0.80418916, 0.28947368],
#        [0.18421053, 0.01287883, 0.02631579],
#        [1.        , 0.86381189, 0.65789474],
#        [0.18421053, 0.99557227, 0.60526316],
#        [0.15789474, 0.6870868 , 0.21052632],
#        [0.86842105, 0.01777158, 0.97368421],
#        [0.        , 0.84308849, 0.47368421],
#        [0.92105263, 0.02763794, 0.28947368],
#        [0.18421053, 0.31899881, 0.55263158],
#        [0.02631579, 0.77556054, 0.        ],
#        [1.        , 0.32799579, 0.63157895],
#        [0.07894737, 0.37926851, 0.57894737],
#        [0.34210526, 1.        , 0.86842105]])

# %%
rawdata = load_iris()
data = pd.DataFrame(rawdata.data,columns=rawdata.feature_names)
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
scaler = MinMaxScalerHM()
scaler.fit(data)

# %%
scaler.transform(data)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0             0.222222          0.625000           0.067797          0.041667
# 1             0.166667          0.416667           0.067797          0.041667
# 2             0.111111          0.500000           0.050847          0.041667
# 3             0.083333          0.458333           0.084746          0.041667
# 4             0.194444          0.666667           0.067797          0.041667
# ..                 ...               ...                ...               ...
# 145           0.666667          0.416667           0.711864          0.916667
# 146           0.555556          0.208333           0.677966          0.750000
# 147           0.611111          0.416667           0.711864          0.791667
# 148           0.527778          0.583333           0.745763          0.916667
# 149           0.444444          0.416667           0.694915          0.708333
#
# [150 rows x 4 columns]

# %%
sk_scaler = MinMaxScaler()
data_scaled = sk_scaler.fit_transform(data)
data_scaled
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...
